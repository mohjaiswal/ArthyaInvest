# %%
# Import necessary libraries
#import PyPDF2
#import re
#import nltk
#from nltk.tokenize import word_tokenize
#from nltk.tag import pos_tag
#from nltk.chunk import ne_chunk
#import fitz  # PyMuPDF

# PDF Extractor
import tabula
# Data Manipulation
import pandas as pd
import numpy as np
# Dashboarding
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

# %%
# Ensure necessary NLTK models are downloaded
#nltk.download('punkt')
#nltk.download('maxent_ne_chunker')
#nltk.download('words')

# %%
def extract_and_combine_tables(pdf_path, page_numbers, new_header):
    combined_table = pd.DataFrame()
    
    for page in page_numbers:
        # Extract table from each page
        tables = tabula.read_pdf(pdf_path, pages=page, multiple_tables=True, lattice=True)
        
        if tables:
            df = tables[0]
            # Delete the first three rows from each page
            df = df.iloc[2:]
            combined_table = pd.concat([combined_table, df], ignore_index=True)
    # Keep only the first 5 columns
    combined_table = combined_table.iloc[:, :5]  

    # Set the new header for the combined table
    combined_table.columns = new_header
    
    return combined_table

# Specify your PDF path
pdf_path = '/Users/mohjaiswal/Desktop/ArthyaInvest/OLA_DRHP.PDF'
pages = [71]  # Pages to extract
new_header = [
    "Balance Sheet", 
    "As at June 30, 2023", 
    "As at March 31, 2023", 
    "As at March 31, 2022", 
    "As at March 31, 2021"
]

# Call the function and assign the result to a variable
df = extract_and_combine_tables(pdf_path, pages, new_header)

# Display the DataFrame
df
# Out:
#                                         Balance Sheet As at June 30, 2023  \
# 0                                              ASSETS                 NaN
# 1                                  Non-current assets                 NaN
# 2                  (a)\rProperty, plant and equipment            8,493.25
# 3                       (b)\rCapital work-in-progress            2,275.88
# 4                            (c)\rRight-of-use assets            1,269.26
# 5                                       (d)\rGoodwill               61.90
# 6                        (e)\rOther intangible assets            1,895.49
# 7            (f)\rIntangible assets under development            4,579.94
# 8                               (g)\rFinancial assets                 NaN
# 9                                    (i)\rInvestments              378.60
# 10                       (ii)\rOther financial assets            1,625.54
# 11                     (h)\rDeferred tax assets (net)                   -
# 12                        (i)\rOther tax assets (net)               55.82
# 13                      (j)\rOther non-current assets            2,629.21
# 14                           Total non-current assets           23,264.89
# 15                                     Current assets                 NaN
# 16                                   (a)\rInventories            6,436.99
# 17                              (b)\rFinancial assets                 NaN
# 18                                   (i)\rInvestments            2,418.80
# 19                            (ii)\rTrade receivables              925.60
# 20                   (iii)\rCash and cash equivalents            2,317.08
# 21         (iv)\rBank balances other than (iii) above            9,084.80
# 22                        (v)\rOther financial assets            7,373.70
# 23                          (c)\rOther current assets            5,289.30
# 24                               Total current assets           33,846.27
# 25                                       Total assets           57,111.16
# 26                                                NaN                 NaN
# 27                             EQUITY AND LIABILITIES                 NaN
# 28                                             EQUITY                 NaN
# 29                          (a)\rEquity share capital           19,554.50
# 30         (b)\rInstruments entirely equity in nature           18,096.97
# 31                                  (c)\rOther equity                 NaN
# 32                    (i)\rOther components of equity            (274.20)
# 33                         (ii)\rReserves and Surplus         (16,258.98)
# 34         (iii)\rItems of other comprehensive income              (3.24)
# 35                                       Total equity           21,115.05
# 36                                                NaN                 NaN
# 37                                        LIABILITIES                 NaN
# 38                            Non-current liabilities                 NaN
# 39                         (a)\rFinancial liabilities                 NaN
# 40                                    (i)\rBorrowings            7,017.36
# 41                            (ii)\rLease liabilities              370.33
# 42                                    (b)\rProvisions               79.18
# 43                 (c)\rOther non-current liabilities            1,261.93
# 44                      Total non-current liabilities            8,728.80
# 45                                                NaN                 NaN
# 46                                Current liabilities                 NaN
# 47                         (a)\rFinancial liabilities                 NaN
# 48                                    (i)\rBorrowings            9,148.37
# 49                            (ii)\rLease liabilities              105.52
# 50                              (iii)\rTrade payables                 NaN
# 51  - total outstanding dues of micro enterprises ...              722.44
# 52  - total outstanding dues of creditors other th...            9,684.46
# 53                  (iv)\rOther financial liabilities            4,447.34
# 54                     (b)\rOther current liabilities            2,179.11
# 55                                    (c)\rProvisions              980.07
# 56                          Total current liabilities           27,267.31
# 57                                  Total liabilities           35,996.11
# 58                       Total equity and liabilities           57,111.16
#
#    As at March 31, 2023 As at March 31, 2022 As at March 31, 2021
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2              8,811.22             7,510.70               175.80
# 3              1,309.14               183.53                48.63
# 4              1,297.87             1,390.03               359.96
# 5                 61.90                61.90               140.75
# 6              2,017.79             1,282.74               365.24
# 7              3,762.64               646.50               378.80
# 8                   NaN                  NaN                  NaN
# 9                378.60               378.60                    -
# 10             1,533.06               251.60                16.30
# 11                    -                    -                    -
# 12                52.86                89.10                83.80
# 13             2,010.27             1,528.62               860.14
# 14            21,235.35            13,323.32             2,429.42
# 15                  NaN                  NaN                  NaN
# 16             5,839.60             2,842.89                32.22
# 17                  NaN                  NaN                  NaN
# 18             2,381.54            10,645.82             4,554.02
# 19               842.54               152.20                 3.80
# 20             2,429.09            12,350.01             3,581.93
# 21            12,863.81             8,617.60            10,077.34
# 22             5,463.05               626.36               263.60
# 23             4,676.71             5,400.43               184.07
# 24            34,496.34            40,635.31            18,696.98
# 25            55,731.69            53,958.63            21,126.40
# 26                  NaN                  NaN                  NaN
# 27                  NaN                  NaN                  NaN
# 28                  NaN                  NaN                  NaN
# 29            19,554.50            19,554.50                 0.10
# 30            18,096.97            18,041.25                 0.07
# 31                  NaN                  NaN                  NaN
# 32             (274.20)             (274.20)             (274.20)
# 33          (13,800.32)             (688.34)            19,992.98
# 34              (12.51)              (18.69)              (12.80)
# 35            23,564.44            36,614.52            19,706.15
# 36                  NaN                  NaN                  NaN
# 37                  NaN                  NaN                  NaN
# 38                  NaN                  NaN                  NaN
# 39                  NaN                  NaN                  NaN
# 40             7,003.31             5,237.90                    -
# 41               398.60               490.37                24.30
# 42                50.50                50.73                18.80
# 43             1,205.80                    -                    -
# 44             8,658.21             5,779.00                43.10
# 45                  NaN                  NaN                  NaN
# 46                  NaN                  NaN                  NaN
# 47                  NaN                  NaN                  NaN
# 48             9,454.22             2,266.17               388.72
# 49               101.61                43.56                 8.70
# 50                  NaN                  NaN                  NaN
# 51               451.04               349.20                 4.50
# 52             6,482.36             3,219.24               427.93
# 53             3,911.73             1,715.10               417.67
# 54             2,309.60             3,386.30                94.92
# 55               798.48               585.54                34.71
# 56            23,509.04            11,565.11             1,377.15
# 57            32,167.25            17,344.11             1,420.25
# 58            55,731.69            53,958.63            21,126.40

# %%
# Assuming 'df' is your DataFrame
# Clean and convert columns
for column in df.columns[1:]:  # Columns after the index
    # Remove unwanted characters (e.g., '$', commas) from the column
    df[column] = df[column].replace('[₹(),]', '', regex=True).replace(' ', '')

    # Convert to numeric, with custom handling for non-numeric data
    df[column] = pd.to_numeric(df[column], errors='coerce').fillna(0)  # Replace NaN with 0

# View the DataFrame
df
# Out:
#                                         Balance Sheet  As at June 30, 2023  \
# 0                                              ASSETS                 0.00
# 1                                  Non-current assets                 0.00
# 2                  (a)\rProperty, plant and equipment              8493.25
# 3                       (b)\rCapital work-in-progress              2275.88
# 4                            (c)\rRight-of-use assets              1269.26
# 5                                       (d)\rGoodwill                61.90
# 6                        (e)\rOther intangible assets              1895.49
# 7            (f)\rIntangible assets under development              4579.94
# 8                               (g)\rFinancial assets                 0.00
# 9                                    (i)\rInvestments               378.60
# 10                       (ii)\rOther financial assets              1625.54
# 11                     (h)\rDeferred tax assets (net)                 0.00
# 12                        (i)\rOther tax assets (net)                55.82
# 13                      (j)\rOther non-current assets              2629.21
# 14                           Total non-current assets             23264.89
# 15                                     Current assets                 0.00
# 16                                   (a)\rInventories              6436.99
# 17                              (b)\rFinancial assets                 0.00
# 18                                   (i)\rInvestments              2418.80
# 19                            (ii)\rTrade receivables               925.60
# 20                   (iii)\rCash and cash equivalents              2317.08
# 21         (iv)\rBank balances other than (iii) above              9084.80
# 22                        (v)\rOther financial assets              7373.70
# 23                          (c)\rOther current assets              5289.30
# 24                               Total current assets             33846.27
# 25                                       Total assets             57111.16
# 26                                                NaN                 0.00
# 27                             EQUITY AND LIABILITIES                 0.00
# 28                                             EQUITY                 0.00
# 29                          (a)\rEquity share capital             19554.50
# 30         (b)\rInstruments entirely equity in nature             18096.97
# 31                                  (c)\rOther equity                 0.00
# 32                    (i)\rOther components of equity               274.20
# 33                         (ii)\rReserves and Surplus             16258.98
# 34         (iii)\rItems of other comprehensive income                 3.24
# 35                                       Total equity             21115.05
# 36                                                NaN                 0.00
# 37                                        LIABILITIES                 0.00
# 38                            Non-current liabilities                 0.00
# 39                         (a)\rFinancial liabilities                 0.00
# 40                                    (i)\rBorrowings              7017.36
# 41                            (ii)\rLease liabilities               370.33
# 42                                    (b)\rProvisions                79.18
# 43                 (c)\rOther non-current liabilities              1261.93
# 44                      Total non-current liabilities              8728.80
# 45                                                NaN                 0.00
# 46                                Current liabilities                 0.00
# 47                         (a)\rFinancial liabilities                 0.00
# 48                                    (i)\rBorrowings              9148.37
# 49                            (ii)\rLease liabilities               105.52
# 50                              (iii)\rTrade payables                 0.00
# 51  - total outstanding dues of micro enterprises ...               722.44
# 52  - total outstanding dues of creditors other th...              9684.46
# 53                  (iv)\rOther financial liabilities              4447.34
# 54                     (b)\rOther current liabilities              2179.11
# 55                                    (c)\rProvisions               980.07
# 56                          Total current liabilities             27267.31
# 57                                  Total liabilities             35996.11
# 58                       Total equity and liabilities             57111.16
#
#     As at March 31, 2023  As at March 31, 2022  As at March 31, 2021
# 0                   0.00                  0.00                  0.00
# 1                   0.00                  0.00                  0.00
# 2                8811.22               7510.70                175.80
# 3                1309.14                183.53                 48.63
# 4                1297.87               1390.03                359.96
# 5                  61.90                 61.90                140.75
# 6                2017.79               1282.74                365.24
# 7                3762.64                646.50                378.80
# 8                   0.00                  0.00                  0.00
# 9                 378.60                378.60                  0.00
# 10               1533.06                251.60                 16.30
# 11                  0.00                  0.00                  0.00
# 12                 52.86                 89.10                 83.80
# 13               2010.27               1528.62                860.14
# 14              21235.35              13323.32               2429.42
# 15                  0.00                  0.00                  0.00
# 16               5839.60               2842.89                 32.22
# 17                  0.00                  0.00                  0.00
# 18               2381.54              10645.82               4554.02
# 19                842.54                152.20                  3.80
# 20               2429.09              12350.01               3581.93
# 21              12863.81               8617.60              10077.34
# 22               5463.05                626.36                263.60
# 23               4676.71               5400.43                184.07
# 24              34496.34              40635.31              18696.98
# 25              55731.69              53958.63              21126.40
# 26                  0.00                  0.00                  0.00
# 27                  0.00                  0.00                  0.00
# 28                  0.00                  0.00                  0.00
# 29              19554.50              19554.50                  0.10
# 30              18096.97              18041.25                  0.07
# 31                  0.00                  0.00                  0.00
# 32                274.20                274.20                274.20
# 33              13800.32                688.34              19992.98
# 34                 12.51                 18.69                 12.80
# 35              23564.44              36614.52              19706.15
# 36                  0.00                  0.00                  0.00
# 37                  0.00                  0.00                  0.00
# 38                  0.00                  0.00                  0.00
# 39                  0.00                  0.00                  0.00
# 40               7003.31               5237.90                  0.00
# 41                398.60                490.37                 24.30
# 42                 50.50                 50.73                 18.80
# 43               1205.80                  0.00                  0.00
# 44               8658.21               5779.00                 43.10
# 45                  0.00                  0.00                  0.00
# 46                  0.00                  0.00                  0.00
# 47                  0.00                  0.00                  0.00
# 48               9454.22               2266.17                388.72
# 49                101.61                 43.56                  8.70
# 50                  0.00                  0.00                  0.00
# 51                451.04                349.20                  4.50
# 52               6482.36               3219.24                427.93
# 53               3911.73               1715.10                417.67
# 54               2309.60               3386.30                 94.92
# 55                798.48                585.54                 34.71
# 56              23509.04              11565.11               1377.15
# 57              32167.25              17344.11               1420.25
# 58              55731.69              53958.63              21126.40

# %%
# Copy the DataFrame
indexed_df = df.copy()

# Set 'Balance Sheet' as the new index for the copied DataFrame
indexed_df.set_index('Balance Sheet', inplace=True)

# Now, indexed_df will have 'Balance Sheet' as its index
# Display the indexed DataFrame to verify the changes
# Set the maximum number of rows to display
pd.set_option('display.max_rows', 62)

# Now when you display the DataFrame, all 62 rows will be shown
indexed_df
# Out:
#                                                     As at June 30, 2023  \
# Balance Sheet
# ASSETS                                                             0.00
# Non-current assets                                                 0.00
# (a)\rProperty, plant and equipment                              8493.25
# (b)\rCapital work-in-progress                                   2275.88
# (c)\rRight-of-use assets                                        1269.26
# (d)\rGoodwill                                                     61.90
# (e)\rOther intangible assets                                    1895.49
# (f)\rIntangible assets under development                        4579.94
# (g)\rFinancial assets                                              0.00
# (i)\rInvestments                                                 378.60
# (ii)\rOther financial assets                                    1625.54
# (h)\rDeferred tax assets (net)                                     0.00
# (i)\rOther tax assets (net)                                       55.82
# (j)\rOther non-current assets                                   2629.21
# Total non-current assets                                       23264.89
# Current assets                                                     0.00
# (a)\rInventories                                                6436.99
# (b)\rFinancial assets                                              0.00
# (i)\rInvestments                                                2418.80
# (ii)\rTrade receivables                                          925.60
# (iii)\rCash and cash equivalents                                2317.08
# (iv)\rBank balances other than (iii) above                      9084.80
# (v)\rOther financial assets                                     7373.70
# (c)\rOther current assets                                       5289.30
# Total current assets                                           33846.27
# Total assets                                                   57111.16
# NaN                                                                0.00
# EQUITY AND LIABILITIES                                             0.00
# EQUITY                                                             0.00
# (a)\rEquity share capital                                      19554.50
# (b)\rInstruments entirely equity in nature                     18096.97
# (c)\rOther equity                                                  0.00
# (i)\rOther components of equity                                  274.20
# (ii)\rReserves and Surplus                                     16258.98
# (iii)\rItems of other comprehensive income                         3.24
# Total equity                                                   21115.05
# NaN                                                                0.00
# LIABILITIES                                                        0.00
# Non-current liabilities                                            0.00
# (a)\rFinancial liabilities                                         0.00
# (i)\rBorrowings                                                 7017.36
# (ii)\rLease liabilities                                          370.33
# (b)\rProvisions                                                   79.18
# (c)\rOther non-current liabilities                              1261.93
# Total non-current liabilities                                   8728.80
# NaN                                                                0.00
# Current liabilities                                                0.00
# (a)\rFinancial liabilities                                         0.00
# (i)\rBorrowings                                                 9148.37
# (ii)\rLease liabilities                                          105.52
# (iii)\rTrade payables                                              0.00
# - total outstanding dues of micro enterprises a...               722.44
# - total outstanding dues of creditors other tha...              9684.46
# (iv)\rOther financial liabilities                               4447.34
# (b)\rOther current liabilities                                  2179.11
# (c)\rProvisions                                                  980.07
# Total current liabilities                                      27267.31
# Total liabilities                                              35996.11
# Total equity and liabilities                                   57111.16
#
#                                                     As at March 31, 2023  \
# Balance Sheet
# ASSETS                                                              0.00
# Non-current assets                                                  0.00
# (a)\rProperty, plant and equipment                               8811.22
# (b)\rCapital work-in-progress                                    1309.14
# (c)\rRight-of-use assets                                         1297.87
# (d)\rGoodwill                                                      61.90
# (e)\rOther intangible assets                                     2017.79
# (f)\rIntangible assets under development                         3762.64
# (g)\rFinancial assets                                               0.00
# (i)\rInvestments                                                  378.60
# (ii)\rOther financial assets                                     1533.06
# (h)\rDeferred tax assets (net)                                      0.00
# (i)\rOther tax assets (net)                                        52.86
# (j)\rOther non-current assets                                    2010.27
# Total non-current assets                                        21235.35
# Current assets                                                      0.00
# (a)\rInventories                                                 5839.60
# (b)\rFinancial assets                                               0.00
# (i)\rInvestments                                                 2381.54
# (ii)\rTrade receivables                                           842.54
# (iii)\rCash and cash equivalents                                 2429.09
# (iv)\rBank balances other than (iii) above                      12863.81
# (v)\rOther financial assets                                      5463.05
# (c)\rOther current assets                                        4676.71
# Total current assets                                            34496.34
# Total assets                                                    55731.69
# NaN                                                                 0.00
# EQUITY AND LIABILITIES                                              0.00
# EQUITY                                                              0.00
# (a)\rEquity share capital                                       19554.50
# (b)\rInstruments entirely equity in nature                      18096.97
# (c)\rOther equity                                                   0.00
# (i)\rOther components of equity                                   274.20
# (ii)\rReserves and Surplus                                      13800.32
# (iii)\rItems of other comprehensive income                         12.51
# Total equity                                                    23564.44
# NaN                                                                 0.00
# LIABILITIES                                                         0.00
# Non-current liabilities                                             0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                  7003.31
# (ii)\rLease liabilities                                           398.60
# (b)\rProvisions                                                    50.50
# (c)\rOther non-current liabilities                               1205.80
# Total non-current liabilities                                    8658.21
# NaN                                                                 0.00
# Current liabilities                                                 0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                  9454.22
# (ii)\rLease liabilities                                           101.61
# (iii)\rTrade payables                                               0.00
# - total outstanding dues of micro enterprises a...                451.04
# - total outstanding dues of creditors other tha...               6482.36
# (iv)\rOther financial liabilities                                3911.73
# (b)\rOther current liabilities                                   2309.60
# (c)\rProvisions                                                   798.48
# Total current liabilities                                       23509.04
# Total liabilities                                               32167.25
# Total equity and liabilities                                    55731.69
#
#                                                     As at March 31, 2022  \
# Balance Sheet
# ASSETS                                                              0.00
# Non-current assets                                                  0.00
# (a)\rProperty, plant and equipment                               7510.70
# (b)\rCapital work-in-progress                                     183.53
# (c)\rRight-of-use assets                                         1390.03
# (d)\rGoodwill                                                      61.90
# (e)\rOther intangible assets                                     1282.74
# (f)\rIntangible assets under development                          646.50
# (g)\rFinancial assets                                               0.00
# (i)\rInvestments                                                  378.60
# (ii)\rOther financial assets                                      251.60
# (h)\rDeferred tax assets (net)                                      0.00
# (i)\rOther tax assets (net)                                        89.10
# (j)\rOther non-current assets                                    1528.62
# Total non-current assets                                        13323.32
# Current assets                                                      0.00
# (a)\rInventories                                                 2842.89
# (b)\rFinancial assets                                               0.00
# (i)\rInvestments                                                10645.82
# (ii)\rTrade receivables                                           152.20
# (iii)\rCash and cash equivalents                                12350.01
# (iv)\rBank balances other than (iii) above                       8617.60
# (v)\rOther financial assets                                       626.36
# (c)\rOther current assets                                        5400.43
# Total current assets                                            40635.31
# Total assets                                                    53958.63
# NaN                                                                 0.00
# EQUITY AND LIABILITIES                                              0.00
# EQUITY                                                              0.00
# (a)\rEquity share capital                                       19554.50
# (b)\rInstruments entirely equity in nature                      18041.25
# (c)\rOther equity                                                   0.00
# (i)\rOther components of equity                                   274.20
# (ii)\rReserves and Surplus                                        688.34
# (iii)\rItems of other comprehensive income                         18.69
# Total equity                                                    36614.52
# NaN                                                                 0.00
# LIABILITIES                                                         0.00
# Non-current liabilities                                             0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                  5237.90
# (ii)\rLease liabilities                                           490.37
# (b)\rProvisions                                                    50.73
# (c)\rOther non-current liabilities                                  0.00
# Total non-current liabilities                                    5779.00
# NaN                                                                 0.00
# Current liabilities                                                 0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                  2266.17
# (ii)\rLease liabilities                                            43.56
# (iii)\rTrade payables                                               0.00
# - total outstanding dues of micro enterprises a...                349.20
# - total outstanding dues of creditors other tha...               3219.24
# (iv)\rOther financial liabilities                                1715.10
# (b)\rOther current liabilities                                   3386.30
# (c)\rProvisions                                                   585.54
# Total current liabilities                                       11565.11
# Total liabilities                                               17344.11
# Total equity and liabilities                                    53958.63
#
#                                                     As at March 31, 2021
# Balance Sheet
# ASSETS                                                              0.00
# Non-current assets                                                  0.00
# (a)\rProperty, plant and equipment                                175.80
# (b)\rCapital work-in-progress                                      48.63
# (c)\rRight-of-use assets                                          359.96
# (d)\rGoodwill                                                     140.75
# (e)\rOther intangible assets                                      365.24
# (f)\rIntangible assets under development                          378.80
# (g)\rFinancial assets                                               0.00
# (i)\rInvestments                                                    0.00
# (ii)\rOther financial assets                                       16.30
# (h)\rDeferred tax assets (net)                                      0.00
# (i)\rOther tax assets (net)                                        83.80
# (j)\rOther non-current assets                                     860.14
# Total non-current assets                                         2429.42
# Current assets                                                      0.00
# (a)\rInventories                                                   32.22
# (b)\rFinancial assets                                               0.00
# (i)\rInvestments                                                 4554.02
# (ii)\rTrade receivables                                             3.80
# (iii)\rCash and cash equivalents                                 3581.93
# (iv)\rBank balances other than (iii) above                      10077.34
# (v)\rOther financial assets                                       263.60
# (c)\rOther current assets                                         184.07
# Total current assets                                            18696.98
# Total assets                                                    21126.40
# NaN                                                                 0.00
# EQUITY AND LIABILITIES                                              0.00
# EQUITY                                                              0.00
# (a)\rEquity share capital                                           0.10
# (b)\rInstruments entirely equity in nature                          0.07
# (c)\rOther equity                                                   0.00
# (i)\rOther components of equity                                   274.20
# (ii)\rReserves and Surplus                                      19992.98
# (iii)\rItems of other comprehensive income                         12.80
# Total equity                                                    19706.15
# NaN                                                                 0.00
# LIABILITIES                                                         0.00
# Non-current liabilities                                             0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                     0.00
# (ii)\rLease liabilities                                            24.30
# (b)\rProvisions                                                    18.80
# (c)\rOther non-current liabilities                                  0.00
# Total non-current liabilities                                      43.10
# NaN                                                                 0.00
# Current liabilities                                                 0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                   388.72
# (ii)\rLease liabilities                                             8.70
# (iii)\rTrade payables                                               0.00
# - total outstanding dues of micro enterprises a...                  4.50
# - total outstanding dues of creditors other tha...                427.93
# (iv)\rOther financial liabilities                                 417.67
# (b)\rOther current liabilities                                     94.92
# (c)\rProvisions                                                    34.71
# Total current liabilities                                        1377.15
# Total liabilities                                                1420.25
# Total equity and liabilities                                    21126.40

# %%
indexed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, ASSETS to Total equity and liabilities
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As at June 30, 2023   59 non-null     float64
#  1   As at March 31, 2023  59 non-null     float64
#  2   As at March 31, 2022  59 non-null     float64
#  3   As at March 31, 2021  59 non-null     float64
# dtypes: float64(4)
# memory usage: 2.3+ KB

# %%
# Define the number of years for CAGR calculation
years = 2  # Adjust this based on your specific data

# Your existing code for calculations
def calculate_change(current, previous):
    if pd.notna(current) and pd.notna(previous) and previous != 0:
        return (current - previous) / previous * 100
    else:
        return 0

indexed_df['YoY 2019-2020'] = indexed_df.apply(lambda row: calculate_change(row[1], row[2]), axis=1)
indexed_df['YoY 2018-2019'] = indexed_df.apply(lambda row: calculate_change(row[2], row[3]), axis=1)
indexed_df['CAGR'] = indexed_df.apply(lambda row: ((row[1] / row[3]) ** (1 / years) - 1) * 100 if pd.notna(row[1]) and pd.notna(row[3]) and row[3] != 0 else 0, axis=1)

# Display the updated DataFrame
indexed_df
# Out:
#                                                     As at June 30, 2023  \
# Balance Sheet
# ASSETS                                                             0.00
# Non-current assets                                                 0.00
# (a)\rProperty, plant and equipment                              8493.25
# (b)\rCapital work-in-progress                                   2275.88
# (c)\rRight-of-use assets                                        1269.26
# (d)\rGoodwill                                                     61.90
# (e)\rOther intangible assets                                    1895.49
# (f)\rIntangible assets under development                        4579.94
# (g)\rFinancial assets                                              0.00
# (i)\rInvestments                                                 378.60
# (ii)\rOther financial assets                                    1625.54
# (h)\rDeferred tax assets (net)                                     0.00
# (i)\rOther tax assets (net)                                       55.82
# (j)\rOther non-current assets                                   2629.21
# Total non-current assets                                       23264.89
# Current assets                                                     0.00
# (a)\rInventories                                                6436.99
# (b)\rFinancial assets                                              0.00
# (i)\rInvestments                                                2418.80
# (ii)\rTrade receivables                                          925.60
# (iii)\rCash and cash equivalents                                2317.08
# (iv)\rBank balances other than (iii) above                      9084.80
# (v)\rOther financial assets                                     7373.70
# (c)\rOther current assets                                       5289.30
# Total current assets                                           33846.27
# Total assets                                                   57111.16
# NaN                                                                0.00
# EQUITY AND LIABILITIES                                             0.00
# EQUITY                                                             0.00
# (a)\rEquity share capital                                      19554.50
# (b)\rInstruments entirely equity in nature                     18096.97
# (c)\rOther equity                                                  0.00
# (i)\rOther components of equity                                  274.20
# (ii)\rReserves and Surplus                                     16258.98
# (iii)\rItems of other comprehensive income                         3.24
# Total equity                                                   21115.05
# NaN                                                                0.00
# LIABILITIES                                                        0.00
# Non-current liabilities                                            0.00
# (a)\rFinancial liabilities                                         0.00
# (i)\rBorrowings                                                 7017.36
# (ii)\rLease liabilities                                          370.33
# (b)\rProvisions                                                   79.18
# (c)\rOther non-current liabilities                              1261.93
# Total non-current liabilities                                   8728.80
# NaN                                                                0.00
# Current liabilities                                                0.00
# (a)\rFinancial liabilities                                         0.00
# (i)\rBorrowings                                                 9148.37
# (ii)\rLease liabilities                                          105.52
# (iii)\rTrade payables                                              0.00
# - total outstanding dues of micro enterprises a...               722.44
# - total outstanding dues of creditors other tha...              9684.46
# (iv)\rOther financial liabilities                               4447.34
# (b)\rOther current liabilities                                  2179.11
# (c)\rProvisions                                                  980.07
# Total current liabilities                                      27267.31
# Total liabilities                                              35996.11
# Total equity and liabilities                                   57111.16
#
#                                                     As at March 31, 2023  \
# Balance Sheet
# ASSETS                                                              0.00
# Non-current assets                                                  0.00
# (a)\rProperty, plant and equipment                               8811.22
# (b)\rCapital work-in-progress                                    1309.14
# (c)\rRight-of-use assets                                         1297.87
# (d)\rGoodwill                                                      61.90
# (e)\rOther intangible assets                                     2017.79
# (f)\rIntangible assets under development                         3762.64
# (g)\rFinancial assets                                               0.00
# (i)\rInvestments                                                  378.60
# (ii)\rOther financial assets                                     1533.06
# (h)\rDeferred tax assets (net)                                      0.00
# (i)\rOther tax assets (net)                                        52.86
# (j)\rOther non-current assets                                    2010.27
# Total non-current assets                                        21235.35
# Current assets                                                      0.00
# (a)\rInventories                                                 5839.60
# (b)\rFinancial assets                                               0.00
# (i)\rInvestments                                                 2381.54
# (ii)\rTrade receivables                                           842.54
# (iii)\rCash and cash equivalents                                 2429.09
# (iv)\rBank balances other than (iii) above                      12863.81
# (v)\rOther financial assets                                      5463.05
# (c)\rOther current assets                                        4676.71
# Total current assets                                            34496.34
# Total assets                                                    55731.69
# NaN                                                                 0.00
# EQUITY AND LIABILITIES                                              0.00
# EQUITY                                                              0.00
# (a)\rEquity share capital                                       19554.50
# (b)\rInstruments entirely equity in nature                      18096.97
# (c)\rOther equity                                                   0.00
# (i)\rOther components of equity                                   274.20
# (ii)\rReserves and Surplus                                      13800.32
# (iii)\rItems of other comprehensive income                         12.51
# Total equity                                                    23564.44
# NaN                                                                 0.00
# LIABILITIES                                                         0.00
# Non-current liabilities                                             0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                  7003.31
# (ii)\rLease liabilities                                           398.60
# (b)\rProvisions                                                    50.50
# (c)\rOther non-current liabilities                               1205.80
# Total non-current liabilities                                    8658.21
# NaN                                                                 0.00
# Current liabilities                                                 0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                  9454.22
# (ii)\rLease liabilities                                           101.61
# (iii)\rTrade payables                                               0.00
# - total outstanding dues of micro enterprises a...                451.04
# - total outstanding dues of creditors other tha...               6482.36
# (iv)\rOther financial liabilities                                3911.73
# (b)\rOther current liabilities                                   2309.60
# (c)\rProvisions                                                   798.48
# Total current liabilities                                       23509.04
# Total liabilities                                               32167.25
# Total equity and liabilities                                    55731.69
#
#                                                     As at March 31, 2022  \
# Balance Sheet
# ASSETS                                                              0.00
# Non-current assets                                                  0.00
# (a)\rProperty, plant and equipment                               7510.70
# (b)\rCapital work-in-progress                                     183.53
# (c)\rRight-of-use assets                                         1390.03
# (d)\rGoodwill                                                      61.90
# (e)\rOther intangible assets                                     1282.74
# (f)\rIntangible assets under development                          646.50
# (g)\rFinancial assets                                               0.00
# (i)\rInvestments                                                  378.60
# (ii)\rOther financial assets                                      251.60
# (h)\rDeferred tax assets (net)                                      0.00
# (i)\rOther tax assets (net)                                        89.10
# (j)\rOther non-current assets                                    1528.62
# Total non-current assets                                        13323.32
# Current assets                                                      0.00
# (a)\rInventories                                                 2842.89
# (b)\rFinancial assets                                               0.00
# (i)\rInvestments                                                10645.82
# (ii)\rTrade receivables                                           152.20
# (iii)\rCash and cash equivalents                                12350.01
# (iv)\rBank balances other than (iii) above                       8617.60
# (v)\rOther financial assets                                       626.36
# (c)\rOther current assets                                        5400.43
# Total current assets                                            40635.31
# Total assets                                                    53958.63
# NaN                                                                 0.00
# EQUITY AND LIABILITIES                                              0.00
# EQUITY                                                              0.00
# (a)\rEquity share capital                                       19554.50
# (b)\rInstruments entirely equity in nature                      18041.25
# (c)\rOther equity                                                   0.00
# (i)\rOther components of equity                                   274.20
# (ii)\rReserves and Surplus                                        688.34
# (iii)\rItems of other comprehensive income                         18.69
# Total equity                                                    36614.52
# NaN                                                                 0.00
# LIABILITIES                                                         0.00
# Non-current liabilities                                             0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                  5237.90
# (ii)\rLease liabilities                                           490.37
# (b)\rProvisions                                                    50.73
# (c)\rOther non-current liabilities                                  0.00
# Total non-current liabilities                                    5779.00
# NaN                                                                 0.00
# Current liabilities                                                 0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                  2266.17
# (ii)\rLease liabilities                                            43.56
# (iii)\rTrade payables                                               0.00
# - total outstanding dues of micro enterprises a...                349.20
# - total outstanding dues of creditors other tha...               3219.24
# (iv)\rOther financial liabilities                                1715.10
# (b)\rOther current liabilities                                   3386.30
# (c)\rProvisions                                                   585.54
# Total current liabilities                                       11565.11
# Total liabilities                                               17344.11
# Total equity and liabilities                                    53958.63
#
#                                                     As at March 31, 2021  \
# Balance Sheet
# ASSETS                                                              0.00
# Non-current assets                                                  0.00
# (a)\rProperty, plant and equipment                                175.80
# (b)\rCapital work-in-progress                                      48.63
# (c)\rRight-of-use assets                                          359.96
# (d)\rGoodwill                                                     140.75
# (e)\rOther intangible assets                                      365.24
# (f)\rIntangible assets under development                          378.80
# (g)\rFinancial assets                                               0.00
# (i)\rInvestments                                                    0.00
# (ii)\rOther financial assets                                       16.30
# (h)\rDeferred tax assets (net)                                      0.00
# (i)\rOther tax assets (net)                                        83.80
# (j)\rOther non-current assets                                     860.14
# Total non-current assets                                         2429.42
# Current assets                                                      0.00
# (a)\rInventories                                                   32.22
# (b)\rFinancial assets                                               0.00
# (i)\rInvestments                                                 4554.02
# (ii)\rTrade receivables                                             3.80
# (iii)\rCash and cash equivalents                                 3581.93
# (iv)\rBank balances other than (iii) above                      10077.34
# (v)\rOther financial assets                                       263.60
# (c)\rOther current assets                                         184.07
# Total current assets                                            18696.98
# Total assets                                                    21126.40
# NaN                                                                 0.00
# EQUITY AND LIABILITIES                                              0.00
# EQUITY                                                              0.00
# (a)\rEquity share capital                                           0.10
# (b)\rInstruments entirely equity in nature                          0.07
# (c)\rOther equity                                                   0.00
# (i)\rOther components of equity                                   274.20
# (ii)\rReserves and Surplus                                      19992.98
# (iii)\rItems of other comprehensive income                         12.80
# Total equity                                                    19706.15
# NaN                                                                 0.00
# LIABILITIES                                                         0.00
# Non-current liabilities                                             0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                     0.00
# (ii)\rLease liabilities                                            24.30
# (b)\rProvisions                                                    18.80
# (c)\rOther non-current liabilities                                  0.00
# Total non-current liabilities                                      43.10
# NaN                                                                 0.00
# Current liabilities                                                 0.00
# (a)\rFinancial liabilities                                          0.00
# (i)\rBorrowings                                                   388.72
# (ii)\rLease liabilities                                             8.70
# (iii)\rTrade payables                                               0.00
# - total outstanding dues of micro enterprises a...                  4.50
# - total outstanding dues of creditors other tha...                427.93
# (iv)\rOther financial liabilities                                 417.67
# (b)\rOther current liabilities                                     94.92
# (c)\rProvisions                                                    34.71
# Total current liabilities                                        1377.15
# Total liabilities                                                1420.25
# Total equity and liabilities                                    21126.40
#
#                                                     YoY 2019-2020  \
# Balance Sheet
# ASSETS                                                   0.000000
# Non-current assets                                       0.000000
# (a)\rProperty, plant and equipment                      17.315563
# (b)\rCapital work-in-progress                          613.311175
# (c)\rRight-of-use assets                                -6.630073
# (d)\rGoodwill                                            0.000000
# (e)\rOther intangible assets                            57.303117
# (f)\rIntangible assets under development               482.001547
# (g)\rFinancial assets                                    0.000000
# (i)\rInvestments                                         0.000000
# (ii)\rOther financial assets                           509.324324
# (h)\rDeferred tax assets (net)                           0.000000
# (i)\rOther tax assets (net)                            -40.673401
# (j)\rOther non-current assets                           31.508812
# Total non-current assets                                59.384823
# Current assets                                           0.000000
# (a)\rInventories                                       105.410691
# (b)\rFinancial assets                                    0.000000
# (i)\rInvestments                                       -77.629342
# (ii)\rTrade receivables                                453.574244
# (iii)\rCash and cash equivalents                       -80.331271
# (iv)\rBank balances other than (iii) above              49.273696
# (v)\rOther financial assets                            772.190114
# (c)\rOther current assets                              -13.401155
# Total current assets                                   -15.107477
# Total assets                                             3.285962
# NaN                                                      0.000000
# EQUITY AND LIABILITIES                                   0.000000
# EQUITY                                                   0.000000
# (a)\rEquity share capital                                0.000000
# (b)\rInstruments entirely equity in nature               0.308848
# (c)\rOther equity                                        0.000000
# (i)\rOther components of equity                          0.000000
# (ii)\rReserves and Surplus                            1904.869686
# (iii)\rItems of other comprehensive income             -33.065811
# Total equity                                           -35.641816
# NaN                                                      0.000000
# LIABILITIES                                              0.000000
# Non-current liabilities                                  0.000000
# (a)\rFinancial liabilities                               0.000000
# (i)\rBorrowings                                         33.704538
# (ii)\rLease liabilities                                -18.714440
# (b)\rProvisions                                         -0.453381
# (c)\rOther non-current liabilities                       0.000000
# Total non-current liabilities                           49.821942
# NaN                                                      0.000000
# Current liabilities                                      0.000000
# (a)\rFinancial liabilities                               0.000000
# (i)\rBorrowings                                        317.189355
# (ii)\rLease liabilities                                133.264463
# (iii)\rTrade payables                                    0.000000
# - total outstanding dues of micro enterprises a...      29.163803
# - total outstanding dues of creditors other tha...     101.363055
# (iv)\rOther financial liabilities                      128.075914
# (b)\rOther current liabilities                         -31.795765
# (c)\rProvisions                                         36.366431
# Total current liabilities                              103.275542
# Total liabilities                                       85.464979
# Total equity and liabilities                             3.285962
#
#                                                     YoY 2018-2019  \
# Balance Sheet
# ASSETS                                               0.000000e+00
# Non-current assets                                   0.000000e+00
# (a)\rProperty, plant and equipment                   4.172298e+03
# (b)\rCapital work-in-progress                        2.774008e+02
# (c)\rRight-of-use assets                             2.861624e+02
# (d)\rGoodwill                                       -5.602131e+01
# (e)\rOther intangible assets                         2.512047e+02
# (f)\rIntangible assets under development             7.067054e+01
# (g)\rFinancial assets                                0.000000e+00
# (i)\rInvestments                                     0.000000e+00
# (ii)\rOther financial assets                         1.443558e+03
# (h)\rDeferred tax assets (net)                       0.000000e+00
# (i)\rOther tax assets (net)                          6.324582e+00
# (j)\rOther non-current assets                        7.771758e+01
# Total non-current assets                             4.484157e+02
# Current assets                                       0.000000e+00
# (a)\rInventories                                     8.723371e+03
# (b)\rFinancial assets                                0.000000e+00
# (i)\rInvestments                                     1.337675e+02
# (ii)\rTrade receivables                              3.905263e+03
# (iii)\rCash and cash equivalents                     2.447865e+02
# (iv)\rBank balances other than (iii) above          -1.448537e+01
# (v)\rOther financial assets                          1.376176e+02
# (c)\rOther current assets                            2.833900e+03
# Total current assets                                 1.173362e+02
# Total assets                                         1.554085e+02
# NaN                                                  0.000000e+00
# EQUITY AND LIABILITIES                               0.000000e+00
# EQUITY                                               0.000000e+00
# (a)\rEquity share capital                            1.955440e+07
# (b)\rInstruments entirely equity in nature           2.577311e+07
# (c)\rOther equity                                    0.000000e+00
# (i)\rOther components of equity                      0.000000e+00
# (ii)\rReserves and Surplus                          -9.655709e+01
# (iii)\rItems of other comprehensive income           4.601563e+01
# Total equity                                         8.580250e+01
# NaN                                                  0.000000e+00
# LIABILITIES                                          0.000000e+00
# Non-current liabilities                              0.000000e+00
# (a)\rFinancial liabilities                           0.000000e+00
# (i)\rBorrowings                                      0.000000e+00
# (ii)\rLease liabilities                              1.917984e+03
# (b)\rProvisions                                      1.698404e+02
# (c)\rOther non-current liabilities                   0.000000e+00
# Total non-current liabilities                        1.330835e+04
# NaN                                                  0.000000e+00
# Current liabilities                                  0.000000e+00
# (a)\rFinancial liabilities                           0.000000e+00
# (i)\rBorrowings                                      4.829826e+02
# (ii)\rLease liabilities                              4.006897e+02
# (iii)\rTrade payables                                0.000000e+00
# - total outstanding dues of micro enterprises a...   7.660000e+03
# - total outstanding dues of creditors other tha...   6.522819e+02
# (iv)\rOther financial liabilities                    3.106352e+02
# (b)\rOther current liabilities                       3.467531e+03
# (c)\rProvisions                                      1.586949e+03
# Total current liabilities                            7.397858e+02
# Total liabilities                                    1.121201e+03
# Total equity and liabilities                         1.554085e+02
#
#                                                             CAGR
# Balance Sheet
# ASSETS                                                  0.000000
# Non-current assets                                      0.000000
# (a)\rProperty, plant and equipment                    607.959782
# (b)\rCapital work-in-progress                         418.848913
# (c)\rRight-of-use assets                               89.884045
# (d)\rGoodwill                                         -33.683572
# (e)\rOther intangible assets                          135.043809
# (f)\rIntangible assets under development              215.167443
# (g)\rFinancial assets                                   0.000000
# (i)\rInvestments                                        0.000000
# (ii)\rOther financial assets                          869.808026
# (h)\rDeferred tax assets (net)                          0.000000
# (i)\rOther tax assets (net)                           -20.577863
# (j)\rOther non-current assets                          52.877166
# Total non-current assets                              195.650359
# Current assets                                          0.000000
# (a)\rInventories                                     1246.259503
# (b)\rFinancial assets                                   0.000000
# (i)\rInvestments                                      -27.684487
# (ii)\rTrade receivables                              1389.030062
# (iii)\rCash and cash equivalents                      -17.650066
# (iv)\rBank balances other than (iii) above             12.982675
# (v)\rOther financial assets                           355.244686
# (c)\rOther current assets                             404.055913
# Total current assets                                   35.831588
# Total assets                                           62.419570
# NaN                                                     0.000000
# EQUITY AND LIABILITIES                                  0.000000
# EQUITY                                                  0.000000
# (a)\rEquity share capital                           44120.470373
# (b)\rInstruments entirely equity in nature          50745.662830
# (c)\rOther equity                                       0.000000
# (i)\rOther components of equity                         0.000000
# (ii)\rReserves and Surplus                            -16.918216
# (iii)\rItems of other comprehensive income             -1.139303
# Total equity                                            9.352236
# NaN                                                     0.000000
# LIABILITIES                                             0.000000
# Non-current liabilities                                 0.000000
# (a)\rFinancial liabilities                              0.000000
# (i)\rBorrowings                                         0.000000
# (ii)\rLease liabilities                               305.009780
# (b)\rProvisions                                        63.895400
# (c)\rOther non-current liabilities                      0.000000
# Total non-current liabilities                        1317.344499
# NaN                                                     0.000000
# Current liabilities                                     0.000000
# (a)\rFinancial liabilities                              0.000000
# (i)\rBorrowings                                       393.167455
# (ii)\rLease liabilities                               241.750060
# (iii)\rTrade payables                                   0.000000
# - total outstanding dues of micro enterprises a...    901.154889
# - total outstanding dues of creditors other tha...    289.206609
# (iv)\rOther financial liabilities                     206.032672
# (b)\rOther current liabilities                        393.275472
# (c)\rProvisions                                       379.628205
# Total current liabilities                             313.168139
# Total liabilities                                     375.909713
# Total equity and liabilities                           62.419570

# %%
indexed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, ASSETS to Total equity and liabilities
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As at June 30, 2023   59 non-null     float64
#  1   As at March 31, 2023  59 non-null     float64
#  2   As at March 31, 2022  59 non-null     float64
#  3   As at March 31, 2021  59 non-null     float64
#  4   YoY 2019-2020         59 non-null     float64
#  5   YoY 2018-2019         59 non-null     float64
#  6   CAGR                  59 non-null     float64
# dtypes: float64(7)
# memory usage: 3.7+ KB

# %% [markdown]
# ## Dashboarding

# %%
print(df.head())
print(df.columns)
# Out:
#                         Balance Sheet  As at June 30, 2023  \
# 0                              ASSETS                 0.00
# 1                  Non-current assets                 0.00
# 2  (a)\rProperty, plant and equipment              8493.25
# 3       (b)\rCapital work-in-progress              2275.88
# 4            (c)\rRight-of-use assets              1269.26
#
#    As at March 31, 2023  As at March 31, 2022  As at March 31, 2021
# 0                  0.00                  0.00                  0.00
# 1                  0.00                  0.00                  0.00
# 2               8811.22               7510.70                175.80
# 3               1309.14                183.53                 48.63
# 4               1297.87               1390.03                359.96
# Index(['Balance Sheet', 'As at June 30, 2023', 'As at March 31, 2023',
#        'As at March 31, 2022', 'As at March 31, 2021'],
#       dtype='object')

# %%
df.set_index('Balance Sheet', inplace=True)

# %%
# Test to access the value for 'Total current assets' using `.at` June 30, 2023
current_assets = df.at['Total current assets', 'As at June 30, 2023']

# Printing the value to verify
print(current_assets)
# Out:
# 33846.27

# %% [markdown]
# ### DashBoarding
# ---
# The terminology you've provided corresponds to the typical line items found in a balance sheet. To adjust the financial ratios using the given terminology, we need to consider how each line item relates to the common financial metrics. Here are the formulas adapted with the provided terminology:
#
# 1. **Current Ratio**:
#    $$ \text{Current Ratio} = \frac{\text{Total Current Assets}}{\text{Total Current Liabilities}} $$
#
# 2. **Quick Ratio**:
#    $$ \text{Quick Ratio} = \frac{\text{Total Current Assets} - \text{Inventories (if listed)}}{\text{Total Current Liabilities}} $$
#    Note: If inventories are not listed separately, they might be part of 'Other current assets' or not applicable.
#
# 3. **Debt-to-Equity Ratio**:
#    $$ \text{Debt-to-Equity Ratio} = \frac{\text{Total Non-current Liabilities} + \text{Total Current Liabilities}}{\text{Equity Attributable to Equity Holders of the Company} + \text{Non-controlling Interests}} $$
#
# 4. **Return on Equity (ROE)**:
#    $$ \text{ROE} = \frac{\text{Net Income}}{\text{Equity Attributable to Equity Holders of the Company} + \text{Non-controlling Interests}} $$
#
# 5. **Return on Assets (ROA)**:
#    $$ \text{ROA} = \frac{\text{Net Income}}{\text{Total Assets}} $$
#
# 6. **Asset Turnover Ratio**:
#    $$ \text{Asset Turnover Ratio} = \frac{\text{Net Sales}}{\text{Total Assets}} $$
#
# 7. **Inventory Turnover Ratio**:
#    (If inventory is part of 'Other current assets', you would need to extract the inventory amount to calculate this ratio.)
#    $$ \text{Inventory Turnover Ratio} = \frac{\text{Cost of Goods Sold}}{\text{Inventory}} $$
#
# 8. **Accounts Receivable Turnover Ratio**:
#    $$ \text{Accounts Receivable Turnover} = \frac{\text{Net Credit Sales}}{\text{Trade Receivables}} $$
#
# 9. **Net Working Capital**:
#    $$ \text{Net Working Capital} = \text{Total Current Assets} - \text{Total Current Liabilities} $$
#
# 10. **Leverage Ratios**:
#     $$ \text{Times Interest Earned} = \frac{\text{EBIT}}{\text{Interest Expense from Borrowings}} $$
#
# **Note**:  Some of the specific line items you might need for these calculations, such as 'Net Income', 'Net Sales', 'Cost of Goods Sold', and 'EBIT' (Earnings Before Interest and Taxes), are not listed in the terminology provided. These would typically be found on the income statement. Additionally, some ratios like Inventory Turnover and Accounts Receivable Turnover depend on more detailed information than what is provided in the balance sheet summary.

# %%
# Initialize the Dash application
app = dash.Dash(__name__)

# Define the layout of the dashboard
app.layout = html.Div(children=[
    html.H1(children='Balance Sheet Dashboard'),

    # Dropdown to select the year for which the metrics are to be displayed
    dcc.Dropdown(
        id='year-dropdown',
        options=[{'label': year, 'value': year} for year in df.columns],
        value=df.columns[0]
    ),
    
    # Div to hold the financial metrics
    html.Div(id='financial-metrics'),

    # Any additional graphs or tables can be added here
    # ...
])

# Define the callback to update the financial metrics
@app.callback(
    Output('financial-metrics', 'children'),
    [Input('year-dropdown', 'value')]
)
def update_financial_metrics(selected_year):
    # Initialize a list to hold the metrics elements
    metrics_list = [html.H3(f"Financial Metrics for {selected_year}")]
    
    # Helper function to safely calculate ratios
    def calculate_ratio(numerator, denominator):
        try:
            return numerator / denominator if denominator != 0 else "Undefined (Denominator is 0)"
        except (TypeError, ValueError):
            return "Data not available"

    # Helper function to get value from DataFrame safely
    def get_value(label, default=0):
        return df.loc[label, selected_year] if label in df.index else default
    
    # Calculate each ratio, handling missing data or errors
    current_ratio = calculate_ratio(get_value('Total current assets'), get_value('Total current liabilities'))
    quick_ratio = calculate_ratio(get_value('Total current assets') - get_value('Inventories'), get_value('Total current liabilities'))
    total_equity = get_value('Total equity')
    total_liabilities = get_value('Total non-current liabilities') + get_value('Total current liabilities')
    debt_to_equity_ratio = calculate_ratio(total_liabilities, total_equity)
    net_income = get_value('Net Income')
    roe = calculate_ratio(net_income, total_equity)
    total_assets = get_value('Total assets')
    roa = calculate_ratio(net_income, total_assets)
    net_sales = get_value('Net Sales')
    asset_turnover_ratio = calculate_ratio(net_sales, total_assets)
    net_working_capital = get_value('Total current assets') - get_value('Total current liabilities')
    
    # Add the calculated metrics to the metrics list
    metrics_list.append(html.P(f"Current Ratio: {current_ratio}"))
    metrics_list.append(html.P(f"Quick Ratio: {quick_ratio}"))
    metrics_list.append(html.P(f"Debt to Equity Ratio: {debt_to_equity_ratio}"))
    metrics_list.append(html.P(f"Return on Equity (ROE): {roe}%"))
    metrics_list.append(html.P(f"Return on Assets (ROA): {roa}%"))
    metrics_list.append(html.P(f"Asset Turnover Ratio: {asset_turnover_ratio}"))
    metrics_list.append(html.P(f"Net Working Capital: {net_working_capital}"))

    return metrics_list

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Note: This is just a gimmick for making the dataframe easy on the eyes where all columns containing 'Total' are made bold. Usually at this stage, the df will be exported to excel 
# Assuming indexed_df is your DataFrame
# Temporarily reset the index for styling
temp_df = indexed_df.reset_index()

# Define a bold styling function
def bold_if_total(row):
    if 'Total' in row.to_string():
        return ['font-weight: bold'] * len(row)
    else:
        return [''] * len(row)

# Apply the styling
bold_df = temp_df.style.apply(bold_if_total, axis=1)

# Display the styled DataFrame
bold_df
# Out:
# <style type="text/css">
# #T_acd20_row14_col0, #T_acd20_row14_col1, #T_acd20_row14_col2, #T_acd20_row14_col3, #T_acd20_row14_col4, #T_acd20_row14_col5, #T_acd20_row14_col6, #T_acd20_row14_col7, #T_acd20_row24_col0, #T_acd20_row24_col1, #T_acd20_row24_col2, #T_acd20_row24_col3, #T_acd20_row24_col4, #T_acd20_row24_col5, #T_acd20_row24_col6, #T_acd20_row24_col7, #T_acd20_row25_col0, #T_acd20_row25_col1, #T_acd20_row25_col2, #T_acd20_row25_col3, #T_acd20_row25_col4, #T_acd20_row25_col5, #T_acd20_row25_col6, #T_acd20_row25_col7, #T_acd20_row35_col0, #T_acd20_row35_col1, #T_acd20_row35_col2, #T_acd20_row35_col3, #T_acd20_row35_col4, #T_acd20_row35_col5, #T_acd20_row35_col6, #T_acd20_row35_col7, #T_acd20_row44_col0, #T_acd20_row44_col1, #T_acd20_row44_col2, #T_acd20_row44_col3, #T_acd20_row44_col4, #T_acd20_row44_col5, #T_acd20_row44_col6, #T_acd20_row44_col7, #T_acd20_row56_col0, #T_acd20_row56_col1, #T_acd20_row56_col2, #T_acd20_row56_col3, #T_acd20_row56_col4, #T_acd20_row56_col5, #T_acd20_row56_col6, #T_acd20_row56_col7, #T_acd20_row57_col0, #T_acd20_row57_col1, #T_acd20_row57_col2, #T_acd20_row57_col3, #T_acd20_row57_col4, #T_acd20_row57_col5, #T_acd20_row57_col6, #T_acd20_row57_col7, #T_acd20_row58_col0, #T_acd20_row58_col1, #T_acd20_row58_col2, #T_acd20_row58_col3, #T_acd20_row58_col4, #T_acd20_row58_col5, #T_acd20_row58_col6, #T_acd20_row58_col7 {
#   font-weight: bold;
# }
# </style>
# <table id="T_acd20_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Balance Sheet</th>
#       <th class="col_heading level0 col1" >As at June 30, 2023</th>
#       <th class="col_heading level0 col2" >As at March 31, 2023</th>
#       <th class="col_heading level0 col3" >As at March 31, 2022</th>
#       <th class="col_heading level0 col4" >As at March 31, 2021</th>
#       <th class="col_heading level0 col5" >YoY 2019-2020</th>
#       <th class="col_heading level0 col6" >YoY 2018-2019</th>
#       <th class="col_heading level0 col7" >CAGR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acd20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acd20_row0_col0" class="data row0 col0" >ASSETS</td>
#       <td id="T_acd20_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_acd20_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_acd20_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_acd20_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_acd20_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_acd20_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_acd20_row0_col7" class="data row0 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_acd20_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_acd20_row1_col0" class="data row1 col0" >Non-current assets</td>
#       <td id="T_acd20_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_acd20_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_acd20_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_acd20_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_acd20_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_acd20_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_acd20_row1_col7" class="data row1 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_acd20_level0_row2" class="row_heading level0 row2" >2</th>
# Property, plant and equipment</td>
#       <td id="T_acd20_row2_col1" class="data row2 col1" >8493.250000</td>
#       <td id="T_acd20_row2_col2" class="data row2 col2" >8811.220000</td>
#       <td id="T_acd20_row2_col3" class="data row2 col3" >7510.700000</td>
#       <td id="T_acd20_row2_col4" class="data row2 col4" >175.800000</td>
#       <td id="T_acd20_row2_col5" class="data row2 col5" >17.315563</td>
#       <td id="T_acd20_row2_col6" class="data row2 col6" >4172.298066</td>
#       <td id="T_acd20_row2_col7" class="data row2 col7" >607.959782</td>
#     </tr>
#     <tr>
#       <th id="T_acd20_level0_row3" class="row_heading level0 row3" >3</th>
# Capital work-in-progress</td>
#       <td id="T_acd20_row3_col1" class="data row3 col1" >2275.880000</td>
#       <td id="T_acd20_row3_col2" class="data row3 col2" >1309.140000</td>
#       <td id="T_acd20_row3_col3" class="data row3 col3" >183.530000</td>
#       <td id="T_acd20_row3_col4" class="data row3 col4" >48.630000</td>
#       <td id="T_acd20_row3_col5" class="data row3 col5" >613.311175</td>
#       <td id="T_acd20_row3_col6" class="data row3 col6" >277.400781</td>
#       <td id="T_acd20_row3_col7" class="data row3 col7" >418.848913</td>
#     </tr>
#     <tr>
#       <th id="T_acd20_level0_row4" class="row_heading level0 row4" >4</th>
# Right-of-use assets</td>
#       <td id="T_acd20_row4_col1" class="data row4 col1" >1269.260000</td>
#       <td id="T_acd20_row4_col2" class="data row4 col2" >1297.870000</td>
#       <td id="T_acd20_row4_col3" class="data row4 col3" >1390.030000</td>
#       <td id="T_acd20_row4_col4" class="data row4 col4" >359.960000</td>
#       <td id="T_acd20_row4_col5" class="data row4 col5" >-6.630073</td>
#       <td id="T_acd20_row4_col6" class="data row4 col6" >286.162351</td>
#       <td id="T_acd20_row4_col7" class="data row4 col7" >89.884045</td>
#     </tr>
#     <tr>
#       <th id="T_acd20_level0_row5" class="row_heading level0 row5" >5</th>
# Goodwill</td>
#       <td id="T_acd20_row5_col1" class="data row5 col1" >61.900000</td>
#       <td id="T_acd20_row5_col2" class="data row5 col2" >61.900000</td>
#       <td id="T_acd20_row5_col3" class="data row5 col3" >61.900000</td>
#       <td id="T_acd20_row5_col4" class="data row5 col4" >140.750000</td>
#       <td id="T_acd20_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_acd20_row5_col6" class="data row5 col6" >-56.021314</td>
#       <td id="T_acd20_row5_col7" class="data row5 col7" >-33.683572</td>
#     </tr>
#     <tr>
#       <th id="T_acd20_level0_row6" class="row_heading level0 row6" >6</th>
# Other intangible assets</td>
#       <td id="T_acd20_row6_col1" class="data row6 col1" >1895.490000</td>
#       <td id="T_acd20_row6_col2" class="data row6 col2" >2017.790000</td>
#       <td id="T_acd20_row6_col3" class="data row6 col3" >1282.740000</td>
#       <td id="T_acd20_row6_col4" class="data row6 col4" >365.240000</td>
#       <td id="T_acd20_row6_col5" class="data row6 col5" >57.303117</td>
#       <td id="T_acd20_row6_col6" class="data row6 col6" >251.204687</td>
#       <td id="T_acd20_row6_col7" class="data row6 col7" >135.043809</td>
#     </tr>
#     <tr>
#       <th id="T_acd20_level0_row7" class="row_heading level0 row7" >7</th>
# Intangible assets under development</td>
#       <td id="T_acd20_row7_col1" class="data row7 col1" >4579.940000</td>
#       <td id="T_acd20_row7_col2" class="data row7 col2" >3762.640000</td>
#       <td id="T_acd20_row7_col3" class="data row7 col3" >646.500000</td>
#       <td id="T_acd20_row7_col4" class="data row7 col4" >378.800000</td>
#       <td id="T_acd20_row7_col5" class="data row7 col5" >482.001547</td>
#       <td id="T_acd20_row7_col6" class="data row7 col6" >70.670539</td>
#       <td id="T_acd20_row7_col7" class="data row7 col7" >215.167443</td>
#     </tr>
#     <tr>
#       <th id="T_acd20_level0_row8" class="row_heading level0 row8" >8</th>
# Financial assets</td>
#       <td id="T_acd20_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_acd20_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_acd20_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_acd20_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_acd20_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_acd20_row8_col6" class="data row8 col6" >0.000000</td>
#       <td id="T_acd20_row8_col7" class="data row8 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_acd20_level0_row9" class="row_heading level0 row9" >9</th>
# Investments</td>
#       <td id="T_acd20_row9_col1" class="data row9 col1" >378.600000</td>
#       <td id="T_acd20_row9_col2" class="dat

# %%
display(temp_df['Balance Sheet'])
# Out:
# 0                                                ASSETS
# 1                                    Non-current assets
# 2                    (a)\rProperty, plant and equipment
# 3                         (b)\rCapital work-in-progress
# 4                              (c)\rRight-of-use assets
# 5                                         (d)\rGoodwill
# 6                          (e)\rOther intangible assets
# 7              (f)\rIntangible assets under development
# 8                                 (g)\rFinancial assets
# 9                                      (i)\rInvestments
# 10                         (ii)\rOther financial assets
# 11                       (h)\rDeferred tax assets (net)
# 12                          (i)\rOther tax assets (net)
# 13                        (j)\rOther non-current assets
# 14                             Total non-current assets
# 15                                       Current assets
# 16                                     (a)\rInventories
# 17                                (b)\rFinancial assets
# 18                                     (i)\rInvestments
# 19                              (ii)\rTrade receivables
# 20                     (iii)\rCash and cash equivalents
# 21           (iv)\rBank balances other than (iii) above
# 22                          (v)\rOther financial assets
# 23                            (c)\rOther current assets
# 24                                 Total current assets
# 25                                         Total assets
# 26                                                  NaN
# 27                               EQUITY AND LIABILITIES
# 28                                               EQUITY
# 29                            (a)\rEquity share capital
# 30           (b)\rInstruments entirely equity in nature
# 31                                    (c)\rOther equity
# 32                      (i)\rOther components of equity
# 33                           (ii)\rReserves and Surplus
# 34           (iii)\rItems of other comprehensive income
# 35                                         Total equity
# 36                                                  NaN
# 37                                          LIABILITIES
# 38                              Non-current liabilities
# 39                           (a)\rFinancial liabilities
# 40                                      (i)\rBorrowings
# 41                              (ii)\rLease liabilities
# 42                                      (b)\rProvisions
# 43                   (c)\rOther non-current liabilities
# 44                        Total non-current liabilities
# 45                                                  NaN
# 46                                  Current liabilities
# 47                           (a)\rFinancial liabilities
# 48                                      (i)\rBorrowings
# 49                              (ii)\rLease liabilities
# 50                                (iii)\rTrade payables
# 51    - total outstanding dues of micro enterprises ...
# 52    - total outstanding dues of creditors other th...
# 53                    (iv)\rOther financial liabilities
# 54                       (b)\rOther current liabilities
# 55                                      (c)\rProvisions
# 56                            Total current liabilities
# 57                                    Total liabilities
# 58                         Total equity and liabilities
# Name: Balance Sheet, dtype: object

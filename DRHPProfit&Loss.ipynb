# %%
# Import necessary libraries
# import PyPDF2
# import re
# import nltk
# from nltk.tokenize import word_tokenize
# from nltk.tag import pos_tag
# from nltk.chunk import ne_chunk
# import fitz  # PyMuPDF
# Dashboarding
# import dash
# from dash import dcc
# from dash import html
# from dash.dependencies import Input, Output

# PDF Extractor
import tabula
# Data Manipulation
import pandas as pd
import numpy as np

# %%
# Ensure necessary NLTK models are downloaded
#nltk.download('punkt')
#nltk.download('maxent_ne_chunker')
#nltk.download('words')

# %%
def extract_and_combine_tables(pdf_path, page_numbers, new_header):
    combined_table = pd.DataFrame()
    
    for page in page_numbers:
        # Extract table from each page
        tables = tabula.read_pdf(pdf_path, pages=page, multiple_tables=True, lattice=True)
        
        if tables:
            df = tables[0]
            # Delete the first three rows from each page
            df = df.iloc[3:]
            combined_table = pd.concat([combined_table, df], ignore_index=True)
    # Keep only the first 5 columns
    combined_table = combined_table.iloc[:, :5]  

    # Set the new header for the combined table
    combined_table.columns = new_header
    
    return combined_table

# Specify your PDF path
pdf_path = '/Users/mohjaiswal/Desktop/ArthyaInvest/dvdfdf.pdf'
pages = [18, 19]  # Pages to extract
new_header = [
    "Profit and Loss", 
    "As at September 30, 2020", 
    "As at March 31, 2020", 
    "As at March 31, 2019", 
    "As at March 31, 2018"
]

# Call the function and assign the result to a variable
df = extract_and_combine_tables(pdf_path, pages, new_header)

# Display the DataFrame
df
# Out:
#                                       Profit and Loss  \
# 0                                              Income
# 1                             Revenue from operations
# 2                                        Other income
# 3                                        Total income
# 4                                                 NaN
# 5                                            Expenses
# 6                       Content, event and web server
# 7                           Advertising and promotion
# 8                                          Commission
# 9                                   Employee benefits
# 10                                      Finance costs
# 11                      Depreciation and amortization
# 12                                             Others
# 13                                     Total expenses
# 14                                                NaN
# 15  Profit/(Loss) before exceptional items, share ...
# 16  Share of loss of Investments accounted using e...
# 17     (Loss)/profit before exceptional items and tax
# 18                                  Exceptional items
# 19                           (Loss)/profit before tax
# 20                                       Tax expense:
# 21                                        Current tax
# 22                                       Deferred tax
# 23                                  Total tax expense
# 24                                                NaN
# 25                                  Net (loss)/profit
# 26                                                NaN
# 27                         Other comprehensive income
# 28                                                NaN
# 29  Items that will not be reclassified to profit ...
# 30  Re-measurements of defined employee benefit plans
# 31  Income tax relating to items that will not be ...
# 32  Items that may be reclassified to profit or loss:
# 33        Net profit/(loss) on FVOCI debt instruments
# 34  Exchange differences in translating the financ...
# 35  Income tax relating to items that will be recl...
# 36            Total other comprehensive income/(loss)
# 37                                                NaN
# 38                  Total comprehensive income/(loss)
# 39                                                NaN
# 40                     Profit/(loss) attributable to:
# 41                  (i) Equity holders of the Company
# 42                      (ii) Non-controlling interest
# 43                                                NaN
# 44  Other comprehensive income/(loss) attributable...
# 45                  (i) Equity holders of the Company
# 46                      (ii) Non-controlling interest
# 47                                                NaN
# 48  Total comprehensive income/(loss) attributable...
# 49                  (i) Equity holders of the Company
# 50                      (ii) Non-controlling interest
# 51                                                NaN
# 52  Earnings per equity share (nominal value of `4...
# 53                                              Basic
# 54                                            Diluted
#
#    As at September 30, 2020 As at March 31, 2020 As at March 31, 2019  \
# 0                       NaN                  NaN                  NaN
# 1                  2,004.57             2,475.09             1,696.98
# 2                     65.49               146.37               164.00
# 3                  2,070.06             2,621.46             1,860.98
# 4                       NaN                  NaN                  NaN
# 5                       NaN                  NaN                  NaN
# 6                    151.97               506.92               442.95
# 7                  1,196.24             1,329.26               272.48
# 8                    222.66                70.72                31.31
# 9                    218.54               318.67               413.84
# 10                     5.11                12.37                13.84
# 11                   187.23               268.81               195.44
# 12                   154.10               304.75               372.94
# 13                 2,135.85             2,811.50             1,742.80
# 14                      NaN                  NaN                  NaN
# 15                  (65.79)             (190.04)               118.18
# 16                  (15.92)              (18.12)               (9.47)
# 17                  (81.71)             (208.16)               108.71
# 18                        -                    -                    -
# 19                  (81.71)             (208.16)               108.71
# 20                      NaN                  NaN                  NaN
# 21                    45.81                55.57                69.65
# 22                  (26.45)                 2.42              (28.07)
# 23                    19.36                57.99                41.58
# 24                      NaN                  NaN                  NaN
# 25                 (101.07)             (266.15)                67.13
# 26                      NaN                  NaN                  NaN
# 27                      NaN                  NaN                  NaN
# 28                      NaN                  NaN                  NaN
# 29                      NaN                  NaN                  NaN
# 30                     0.34                 1.00               (1.69)
# 31                   (0.38)               (0.27)               (0.45)
# 32                      NaN                  NaN                  NaN
# 33                   (1.34)                14.38                 0.23
# 34                  (41.38)               146.19               114.81
# 35                        -                    -                    -
# 36                  (42.46)               161.30               112.90
# 37                      NaN                  NaN                  NaN
# 38                 (143.53)             (104.85)               180.03
# 39                      NaN                  NaN                  NaN
# 40                      NaN                  NaN                  NaN
# 41                  (50.15)              (21.26)               175.08
# 42                  (50.92)             (244.89)             (107.95)
# 43                      NaN                  NaN                  NaN
# 44                      NaN                  NaN                  NaN
# 45                  (42.46)               161.30               112.90
# 46                        -                    -                    -
# 47                      NaN                  NaN                  NaN
# 48                      NaN                  NaN                  NaN
# 49                  (92.61)               140.04               287.98
# 50                  (50.92)             (244.89)             (107.95)
# 51                      NaN                  NaN                  NaN
# 52                      NaN                  NaN                  NaN
# 53                   (1.78)               (0.77)                 6.39
# 54                   (1.78)               (0.77)                 6.27
#
#    As at March 31, 2018
# 0                   NaN
# 1              1,720.40
# 2                 99.00
# 3              1,819.40
# 4                   NaN
# 5                   NaN
# 6                121.35
# 7                427.80
# 8                 32.26
# 9                371.97
# 10                18.34
# 11                82.16
# 12               279.84
# 13             1,333.72
# 14                  NaN
# 15               485.68
# 16               (0.63)
# 17               485.05
# 18             (357.18)
# 19               127.87
# 20                  NaN
# 21               143.65
# 22              (26.01)
# 23               117.64
# 24                  NaN
# 25                10.23
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                 0.21
# 31               (0.07)
# 32                  NaN
# 33               (1.31)
# 34                16.81
# 35                    -
# 36                15.64
# 37                  NaN
# 38                25.87
# 39                  NaN
# 40                  NaN
# 41                26.70
# 42              (16.47)
# 43                  NaN
# 44                  NaN
# 45                15.64
# 46                    -
# 47                  NaN
# 48                  NaN
# 49                42.34
# 50              (16.47)
# 51                  NaN
# 52                  NaN
# 53                 1.05
# 54                 1.04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Profit and Loss           45 non-null     object
#  1   As at September 30, 2020  35 non-null     object
#  2   As at March 31, 2020      35 non-null     object
#  3   As at March 31, 2019      35 non-null     object
#  4   As at March 31, 2018      35 non-null     object
# dtypes: object(5)
# memory usage: 2.3+ KB

# %%
# Copy the DataFrame
indexed_df = df.copy()

# Set 'Balance Sheet' as the new index for the copied DataFrame
indexed_df.set_index('Profit and Loss', inplace=True)

# Now, indexed_df will have 'Balance Sheet' as its index
# Display the indexed DataFrame to verify the changes
# Set the maximum number of rows to display all the important data points
pd.set_option('display.max_rows', 100)

# Now when you display the DataFrame, all 100 rows will be shown
indexed_df
# Out:
#                                                    As at September 30, 2020  \
# Profit and Loss
# Income                                                                  NaN
# Revenue from operations                                            2,004.57
# Other income                                                          65.49
# Total income                                                       2,070.06
# NaN                                                                     NaN
# Expenses                                                                NaN
# Content, event and web server                                        151.97
# Advertising and promotion                                          1,196.24
# Commission                                                           222.66
# Employee benefits                                                    218.54
# Finance costs                                                          5.11
# Depreciation and amortization                                        187.23
# Others                                                               154.10
# Total expenses                                                     2,135.85
# NaN                                                                     NaN
# Profit/(Loss) before exceptional items, share o...                  (65.79)
# Share of loss of Investments accounted using eq...                  (15.92)
# (Loss)/profit before exceptional items and tax                      (81.71)
# Exceptional items                                                         -
# (Loss)/profit before tax                                            (81.71)
# Tax expense:                                                            NaN
# Current tax                                                           45.81
# Deferred tax                                                        (26.45)
# Total tax expense                                                     19.36
# NaN                                                                     NaN
# Net (loss)/profit                                                  (101.07)
# NaN                                                                     NaN
# Other comprehensive income                                              NaN
# NaN                                                                     NaN
# Items that will not be reclassified to profit a...                      NaN
# Re-measurements of defined employee benefit plans                      0.34
# Income tax relating to items that will not be r...                   (0.38)
# Items that may be reclassified to profit or loss:                       NaN
# Net profit/(loss) on FVOCI debt instruments                          (1.34)
# Exchange differences in translating the financi...                  (41.38)
# Income tax relating to items that will be recla...                        -
# Total other comprehensive income/(loss)                             (42.46)
# NaN                                                                     NaN
# Total comprehensive income/(loss)                                  (143.53)
# NaN                                                                     NaN
# Profit/(loss) attributable to:                                          NaN
# (i) Equity holders of the Company                                   (50.15)
# (ii) Non-controlling interest                                       (50.92)
# NaN                                                                     NaN
# Other comprehensive income/(loss) attributable to:                      NaN
# (i) Equity holders of the Company                                   (42.46)
# (ii) Non-controlling interest                                             -
# NaN                                                                     NaN
# Total comprehensive income/(loss) attributable to:                      NaN
# (i) Equity holders of the Company                                   (92.61)
# (ii) Non-controlling interest                                       (50.92)
# NaN                                                                     NaN
# Earnings per equity share (nominal value of `4 ...                      NaN
# Basic                                                                (1.78)
# Diluted                                                              (1.78)
#
#                                                    As at March 31, 2020  \
# Profit and Loss
# Income                                                              NaN
# Revenue from operations                                        2,475.09
# Other income                                                     146.37
# Total income                                                   2,621.46
# NaN                                                                 NaN
# Expenses                                                            NaN
# Content, event and web server                                    506.92
# Advertising and promotion                                      1,329.26
# Commission                                                        70.72
# Employee benefits                                                318.67
# Finance costs                                                     12.37
# Depreciation and amortization                                    268.81
# Others                                                           304.75
# Total expenses                                                 2,811.50
# NaN                                                                 NaN
# Profit/(Loss) before exceptional items, share o...             (190.04)
# Share of loss of Investments accounted using eq...              (18.12)
# (Loss)/profit before exceptional items and tax                 (208.16)
# Exceptional items                                                     -
# (Loss)/profit before tax                                       (208.16)
# Tax expense:                                                        NaN
# Current tax                                                       55.57
# Deferred tax                                                       2.42
# Total tax expense                                                 57.99
# NaN                                                                 NaN
# Net (loss)/profit                                              (266.15)
# NaN                                                                 NaN
# Other comprehensive income                                          NaN
# NaN                                                                 NaN
# Items that will not be reclassified to profit a...                  NaN
# Re-measurements of defined employee benefit plans                  1.00
# Income tax relating to items that will not be r...               (0.27)
# Items that may be reclassified to profit or loss:                   NaN
# Net profit/(loss) on FVOCI debt instruments                       14.38
# Exchange differences in translating the financi...               146.19
# Income tax relating to items that will be recla...                    -
# Total other comprehensive income/(loss)                          161.30
# NaN                                                                 NaN
# Total comprehensive income/(loss)                              (104.85)
# NaN                                                                 NaN
# Profit/(loss) attributable to:                                      NaN
# (i) Equity holders of the Company                               (21.26)
# (ii) Non-controlling interest                                  (244.89)
# NaN                                                                 NaN
# Other comprehensive income/(loss) attributable to:                  NaN
# (i) Equity holders of the Company                                161.30
# (ii) Non-controlling interest                                         -
# NaN                                                                 NaN
# Total comprehensive income/(loss) attributable to:                  NaN
# (i) Equity holders of the Company                                140.04
# (ii) Non-controlling interest                                  (244.89)
# NaN                                                                 NaN
# Earnings per equity share (nominal value of `4 ...                  NaN
# Basic                                                            (0.77)
# Diluted                                                          (0.77)
#
#                                                    As at March 31, 2019  \
# Profit and Loss
# Income                                                              NaN
# Revenue from operations                                        1,696.98
# Other income                                                     164.00
# Total income                                                   1,860.98
# NaN                                                                 NaN
# Expenses                                                            NaN
# Content, event and web server                                    442.95
# Advertising and promotion                                        272.48
# Commission                                                        31.31
# Employee benefits                                                413.84
# Finance costs                                                     13.84
# Depreciation and amortization                                    195.44
# Others                                                           372.94
# Total expenses                                                 1,742.80
# NaN                                                                 NaN
# Profit/(Loss) before exceptional items, share o...               118.18
# Share of loss of Investments accounted using eq...               (9.47)
# (Loss)/profit before exceptional items and tax                   108.71
# Exceptional items                                                     -
# (Loss)/profit before tax                                         108.71
# Tax expense:                                                        NaN
# Current tax                                                       69.65
# Deferred tax                                                    (28.07)
# Total tax expense                                                 41.58
# NaN                                                                 NaN
# Net (loss)/profit                                                 67.13
# NaN                                                                 NaN
# Other comprehensive income                                          NaN
# NaN                                                                 NaN
# Items that will not be reclassified to profit a...                  NaN
# Re-measurements of defined employee benefit plans                (1.69)
# Income tax relating to items that will not be r...               (0.45)
# Items that may be reclassified to profit or loss:                   NaN
# Net profit/(loss) on FVOCI debt instruments                        0.23
# Exchange differences in translating the financi...               114.81
# Income tax relating to items that will be recla...                    -
# Total other comprehensive income/(loss)                          112.90
# NaN                                                                 NaN
# Total comprehensive income/(loss)                                180.03
# NaN                                                                 NaN
# Profit/(loss) attributable to:                                      NaN
# (i) Equity holders of the Company                                175.08
# (ii) Non-controlling interest                                  (107.95)
# NaN                                                                 NaN
# Other comprehensive income/(loss) attributable to:                  NaN
# (i) Equity holders of the Company                                112.90
# (ii) Non-controlling interest                                         -
# NaN                                                                 NaN
# Total comprehensive income/(loss) attributable to:                  NaN
# (i) Equity holders of the Company                                287.98
# (ii) Non-controlling interest                                  (107.95)
# NaN                                                                 NaN
# Earnings per equity share (nominal value of `4 ...                  NaN
# Basic                                                              6.39
# Diluted                                                            6.27
#
#                                                    As at March 31, 2018
# Profit and Loss
# Income                                                              NaN
# Revenue from operations                                        1,720.40
# Other income                                                      99.00
# Total income                                                   1,819.40
# NaN                                                                 NaN
# Expenses                                                            NaN
# Content, event and web server                                    121.35
# Advertising and promotion                                        427.80
# Commission                                                        32.26
# Employee benefits                                                371.97
# Finance costs                                                     18.34
# Depreciation and amortization                                     82.16
# Others                                                           279.84
# Total expenses                                                 1,333.72
# NaN                                                                 NaN
# Profit/(Loss) before exceptional items, share o...               485.68
# Share of loss of Investments accounted using eq...               (0.63)
# (Loss)/profit before exceptional items and tax                   485.05
# Exceptional items                                              (357.18)
# (Loss)/profit before tax                                         127.87
# Tax expense:                                                        NaN
# Current tax                                                      143.65
# Deferred tax                                                    (26.01)
# Total tax expense                                                117.64
# NaN                                                                 NaN
# Net (loss)/profit                                                 10.23
# NaN                                                                 NaN
# Other comprehensive income                                          NaN
# NaN                                                                 NaN
# Items that will not be reclassified to profit a...                  NaN
# Re-measurements of defined employee benefit plans                  0.21
# Income tax relating to items that will not be r...               (0.07)
# Items that may be reclassified to profit or loss:                   NaN
# Net profit/(loss) on FVOCI debt instruments                      (1.31)
# Exchange differences in translating the financi...                16.81
# Income tax relating to items that will be recla...                    -
# Total other comprehensive income/(loss)                           15.64
# NaN                                                                 NaN
# Total comprehensive income/(loss)                                 25.87
# NaN                                                                 NaN
# Profit/(loss) attributable to:                                      NaN
# (i) Equity holders of the Company                                 26.70
# (ii) Non-controlling interest                                   (16.47)
# NaN                                                                 NaN
# Other comprehensive income/(loss) attributable to:                  NaN
# (i) Equity holders of the Company                                 15.64
# (ii) Non-controlling interest                                         -
# NaN                                                                 NaN
# Total comprehensive income/(loss) attributable to:                  NaN
# (i) Equity holders of the Company                                 42.34
# (ii) Non-controlling interest                                   (16.47)
# NaN                                                                 NaN
# Earnings per equity share (nominal value of `4 ...                  NaN
# Basic                                                              1.05
# Diluted                                                            1.04

# %%
# Remove backticks from the index
indexed_df.index = indexed_df.index.astype(str).str.replace('`', '')

# Check the result
print(indexed_df.index)
# Out:
# Index(['Income', 'Revenue from operations', 'Other income', 'Total income',
#        'nan', 'Expenses', 'Content, event and web server',
#        'Advertising and promotion', 'Commission', 'Employee benefits',
#        'Finance costs', 'Depreciation and amortization', 'Others',
#        'Total expenses', 'nan',
#        'Profit/(Loss) before exceptional items, share of net\rprofit/(losses) of investments accounted for using the\requity method and tax',
#        'Share of loss of Investments accounted using equity\rmethod (net)',
#        '(Loss)/profit before exceptional items and tax', 'Exceptional items',
#        '(Loss)/profit before tax', 'Tax expense:', 'Current tax',
#        'Deferred tax', 'Total tax expense', 'nan', 'Net (loss)/profit', 'nan',
#        'Other comprehensive income', 'nan',
#        'Items that will not be reclassified to profit and loss:',
#        'Re-measurements of defined employee benefit plans',
#        'Income tax relating to items that will not be reclassified to\rprofit or loss',
#        'Items that may be reclassified to profit or loss:',
#        'Net profit/(loss) on FVOCI debt instruments',
#        'Exchange differences in translating the financial\rstatements of a foreign operation',
#        'Income tax relating to items that will be reclassified to\rprofit and loss',
#        'Total other comprehensive income/(loss)', 'nan',
#        'Total comprehensive income/(loss)', 'nan',
#        'Profit/(loss) attributable to:', '(i) Equity holders of the Company',
#        '(ii) Non-controlling interest', 'nan',
#        'Other comprehensive income/(loss) attributable to:',
#        '(i) Equity holders of the Company', '(ii) Non-controlling interest',
#        'nan', 'Total comprehensive income/(loss) attributable to:',
#        '(i) Equity holders of the Company', '(ii) Non-controlling interest',
#        'nan', 'Earnings per equity share (nominal value of 4 each):', 'Basic',
#        'Diluted'],
#       dtype='object', name='Profit and Loss')

# %%
indexed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, Income to Diluted
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   As at September 30, 2020  35 non-null     object
#  1   As at March 31, 2020      35 non-null     object
#  2   As at March 31, 2019      35 non-null     object
#  3   As at March 31, 2018      35 non-null     object
# dtypes: object(4)
# memory usage: 2.1+ KB

# %%
# Define a function to clean and convert the values to float
def clean_convert_value(x):
    if isinstance(x, str):
        if x == '-':
            # Convert '-' to NaN
            return np.nan
        x = x.replace('₹', '').replace(',', '')
        if '(' in x and ')' in x:
            return -float(x.replace('(', '').replace(')', ''))
        else:
            return float(x)
    elif pd.isna(x):
        return x
    else:
        return float(x)

# Convert columns 0 to 3 to float
for column in indexed_df.columns[0:4]:  # Selecting columns 0 to 3
    indexed_df[column] = indexed_df[column].apply(clean_convert_value)

# Check the data types and DataFrame
print(indexed_df.dtypes)
indexed_df
# Out:
# As at September 30, 2020    float64
# As at March 31, 2020        float64
# As at March 31, 2019        float64
# As at March 31, 2018        float64
# dtype: object
#                                                     As at September 30, 2020  \
# Profit and Loss
# Income                                                                   NaN
# Revenue from operations                                              2004.57
# Other income                                                           65.49
# Total income                                                         2070.06
# nan                                                                      NaN
# Expenses                                                                 NaN
# Content, event and web server                                         151.97
# Advertising and promotion                                            1196.24
# Commission                                                            222.66
# Employee benefits                                                     218.54
# Finance costs                                                           5.11
# Depreciation and amortization                                         187.23
# Others                                                                154.10
# Total expenses                                                       2135.85
# nan                                                                      NaN
# Profit/(Loss) before exceptional items, share o...                    -65.79
# Share of loss of Investments accounted using eq...                    -15.92
# (Loss)/profit before exceptional items and tax                        -81.71
# Exceptional items                                                        NaN
# (Loss)/profit before tax                                              -81.71
# Tax expense:                                                             NaN
# Current tax                                                            45.81
# Deferred tax                                                          -26.45
# Total tax expense                                                      19.36
# nan                                                                      NaN
# Net (loss)/profit                                                    -101.07
# nan                                                                      NaN
# Other comprehensive income                                               NaN
# nan                                                                      NaN
# Items that will not be reclassified to profit a...                       NaN
# Re-measurements of defined employee benefit plans                       0.34
# Income tax relating to items that will not be r...                     -0.38
# Items that may be reclassified to profit or loss:                        NaN
# Net profit/(loss) on FVOCI debt instruments                            -1.34
# Exchange differences in translating the financi...                    -41.38
# Income tax relating to items that will be recla...                       NaN
# Total other comprehensive income/(loss)                               -42.46
# nan                                                                      NaN
# Total comprehensive income/(loss)                                    -143.53
# nan                                                                      NaN
# Profit/(loss) attributable to:                                           NaN
# (i) Equity holders of the Company                                     -50.15
# (ii) Non-controlling interest                                         -50.92
# nan                                                                      NaN
# Other comprehensive income/(loss) attributable to:                       NaN
# (i) Equity holders of the Company                                     -42.46
# (ii) Non-controlling interest                                            NaN
# nan                                                                      NaN
# Total comprehensive income/(loss) attributable to:                       NaN
# (i) Equity holders of the Company                                     -92.61
# (ii) Non-controlling interest                                         -50.92
# nan                                                                      NaN
# Earnings per equity share (nominal value of 4 e...                       NaN
# Basic                                                                  -1.78
# Diluted                                                                -1.78
#
#                                                     As at March 31, 2020  \
# Profit and Loss
# Income                                                               NaN
# Revenue from operations                                          2475.09
# Other income                                                      146.37
# Total income                                                     2621.46
# nan                                                                  NaN
# Expenses                                                             NaN
# Content, event and web server                                     506.92
# Advertising and promotion                                        1329.26
# Commission                                                         70.72
# Employee benefits                                                 318.67
# Finance costs                                                      12.37
# Depreciation and amortization                                     268.81
# Others                                                            304.75
# Total expenses                                                   2811.50
# nan                                                                  NaN
# Profit/(Loss) before exceptional items, share o...               -190.04
# Share of loss of Investments accounted using eq...                -18.12
# (Loss)/profit before exceptional items and tax                   -208.16
# Exceptional items                                                    NaN
# (Loss)/profit before tax                                         -208.16
# Tax expense:                                                         NaN
# Current tax                                                        55.57
# Deferred tax                                                        2.42
# Total tax expense                                                  57.99
# nan                                                                  NaN
# Net (loss)/profit                                                -266.15
# nan                                                                  NaN
# Other comprehensive income                                           NaN
# nan                                                                  NaN
# Items that will not be reclassified to profit a...                   NaN
# Re-measurements of defined employee benefit plans                   1.00
# Income tax relating to items that will not be r...                 -0.27
# Items that may be reclassified to profit or loss:                    NaN
# Net profit/(loss) on FVOCI debt instruments                        14.38
# Exchange differences in translating the financi...                146.19
# Income tax relating to items that will be recla...                   NaN
# Total other comprehensive income/(loss)                           161.30
# nan                                                                  NaN
# Total comprehensive income/(loss)                                -104.85
# nan                                                                  NaN
# Profit/(loss) attributable to:                                       NaN
# (i) Equity holders of the Company                                 -21.26
# (ii) Non-controlling interest                                    -244.89
# nan                                                                  NaN
# Other comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                 161.30
# (ii) Non-controlling interest                                        NaN
# nan                                                                  NaN
# Total comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                 140.04
# (ii) Non-controlling interest                                    -244.89
# nan                                                                  NaN
# Earnings per equity share (nominal value of 4 e...                   NaN
# Basic                                                              -0.77
# Diluted                                                            -0.77
#
#                                                     As at March 31, 2019  \
# Profit and Loss
# Income                                                               NaN
# Revenue from operations                                          1696.98
# Other income                                                      164.00
# Total income                                                     1860.98
# nan                                                                  NaN
# Expenses                                                             NaN
# Content, event and web server                                     442.95
# Advertising and promotion                                         272.48
# Commission                                                         31.31
# Employee benefits                                                 413.84
# Finance costs                                                      13.84
# Depreciation and amortization                                     195.44
# Others                                                            372.94
# Total expenses                                                   1742.80
# nan                                                                  NaN
# Profit/(Loss) before exceptional items, share o...                118.18
# Share of loss of Investments accounted using eq...                 -9.47
# (Loss)/profit before exceptional items and tax                    108.71
# Exceptional items                                                    NaN
# (Loss)/profit before tax                                          108.71
# Tax expense:                                                         NaN
# Current tax                                                        69.65
# Deferred tax                                                      -28.07
# Total tax expense                                                  41.58
# nan                                                                  NaN
# Net (loss)/profit                                                  67.13
# nan                                                                  NaN
# Other comprehensive income                                           NaN
# nan                                                                  NaN
# Items that will not be reclassified to profit a...                   NaN
# Re-measurements of defined employee benefit plans                  -1.69
# Income tax relating to items that will not be r...                 -0.45
# Items that may be reclassified to profit or loss:                    NaN
# Net profit/(loss) on FVOCI debt instruments                         0.23
# Exchange differences in translating the financi...                114.81
# Income tax relating to items that will be recla...                   NaN
# Total other comprehensive income/(loss)                           112.90
# nan                                                                  NaN
# Total comprehensive income/(loss)                                 180.03
# nan                                                                  NaN
# Profit/(loss) attributable to:                                       NaN
# (i) Equity holders of the Company                                 175.08
# (ii) Non-controlling interest                                    -107.95
# nan                                                                  NaN
# Other comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                 112.90
# (ii) Non-controlling interest                                        NaN
# nan                                                                  NaN
# Total comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                 287.98
# (ii) Non-controlling interest                                    -107.95
# nan                                                                  NaN
# Earnings per equity share (nominal value of 4 e...                   NaN
# Basic                                                               6.39
# Diluted                                                             6.27
#
#                                                     As at March 31, 2018
# Profit and Loss
# Income                                                               NaN
# Revenue from operations                                          1720.40
# Other income                                                       99.00
# Total income                                                     1819.40
# nan                                                                  NaN
# Expenses                                                             NaN
# Content, event and web server                                     121.35
# Advertising and promotion                                         427.80
# Commission                                                         32.26
# Employee benefits                                                 371.97
# Finance costs                                                      18.34
# Depreciation and amortization                                      82.16
# Others                                                            279.84
# Total expenses                                                   1333.72
# nan                                                                  NaN
# Profit/(Loss) before exceptional items, share o...                485.68
# Share of loss of Investments accounted using eq...                 -0.63
# (Loss)/profit before exceptional items and tax                    485.05
# Exceptional items                                                -357.18
# (Loss)/profit before tax                                          127.87
# Tax expense:                                                         NaN
# Current tax                                                       143.65
# Deferred tax                                                      -26.01
# Total tax expense                                                 117.64
# nan                                                                  NaN
# Net (loss)/profit                                                  10.23
# nan                                                                  NaN
# Other comprehensive income                                           NaN
# nan                                                                  NaN
# Items that will not be reclassified to profit a...                   NaN
# Re-measurements of defined employee benefit plans                   0.21
# Income tax relating to items that will not be r...                 -0.07
# Items that may be reclassified to profit or loss:                    NaN
# Net profit/(loss) on FVOCI debt instruments                        -1.31
# Exchange differences in translating the financi...                 16.81
# Income tax relating to items that will be recla...                   NaN
# Total other comprehensive income/(loss)                            15.64
# nan                                                                  NaN
# Total comprehensive income/(loss)                                  25.87
# nan                                                                  NaN
# Profit/(loss) attributable to:                                       NaN
# (i) Equity holders of the Company                                  26.70
# (ii) Non-controlling interest                                     -16.47
# nan                                                                  NaN
# Other comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                  15.64
# (ii) Non-controlling interest                                        NaN
# nan                                                                  NaN
# Total comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                  42.34
# (ii) Non-controlling interest                                     -16.47
# nan                                                                  NaN
# Earnings per equity share (nominal value of 4 e...                   NaN
# Basic                                                               1.05
# Diluted                                                             1.04

# %%
indexed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, Income to Diluted
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   As at September 30, 2020  32 non-null     float64
#  1   As at March 31, 2020      32 non-null     float64
#  2   As at March 31, 2019      32 non-null     float64
#  3   As at March 31, 2018      33 non-null     float64
# dtypes: float64(4)
# memory usage: 2.1+ KB

# %%
# Define the number of years for CAGR calculation
years = 2  # Adjust this based on your specific data

# Your existing code for calculations
def calculate_change(current, previous):
    if pd.notna(current) and pd.notna(previous) and previous != 0:
        return (current - previous) / previous * 100
    else:
        return 0

indexed_df['YoY 2019-2020'] = indexed_df.apply(lambda row: calculate_change(row[1], row[2]), axis=1)
indexed_df['YoY 2018-2019'] = indexed_df.apply(lambda row: calculate_change(row[2], row[3]), axis=1)
indexed_df['CAGR'] = indexed_df.apply(lambda row: ((row[1] / row[3]) ** (1 / years) - 1) * 100 if pd.notna(row[1]) and pd.notna(row[3]) and row[3] != 0 else 0, axis=1)

# Display the updated DataFrame
indexed_df
# Out:
# /Users/mohjaiswal/opt/anaconda3/envs/dev2/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   del sys.path[0]
#                                                     As at September 30, 2020  \
# Profit and Loss
# Income                                                                   NaN
# Revenue from operations                                              2004.57
# Other income                                                           65.49
# Total income                                                         2070.06
# nan                                                                      NaN
# Expenses                                                                 NaN
# Content, event and web server                                         151.97
# Advertising and promotion                                            1196.24
# Commission                                                            222.66
# Employee benefits                                                     218.54
# Finance costs                                                           5.11
# Depreciation and amortization                                         187.23
# Others                                                                154.10
# Total expenses                                                       2135.85
# nan                                                                      NaN
# Profit/(Loss) before exceptional items, share o...                    -65.79
# Share of loss of Investments accounted using eq...                    -15.92
# (Loss)/profit before exceptional items and tax                        -81.71
# Exceptional items                                                        NaN
# (Loss)/profit before tax                                              -81.71
# Tax expense:                                                             NaN
# Current tax                                                            45.81
# Deferred tax                                                          -26.45
# Total tax expense                                                      19.36
# nan                                                                      NaN
# Net (loss)/profit                                                    -101.07
# nan                                                                      NaN
# Other comprehensive income                                               NaN
# nan                                                                      NaN
# Items that will not be reclassified to profit a...                       NaN
# Re-measurements of defined employee benefit plans                       0.34
# Income tax relating to items that will not be r...                     -0.38
# Items that may be reclassified to profit or loss:                        NaN
# Net profit/(loss) on FVOCI debt instruments                            -1.34
# Exchange differences in translating the financi...                    -41.38
# Income tax relating to items that will be recla...                       NaN
# Total other comprehensive income/(loss)                               -42.46
# nan                                                                      NaN
# Total comprehensive income/(loss)                                    -143.53
# nan                                                                      NaN
# Profit/(loss) attributable to:                                           NaN
# (i) Equity holders of the Company                                     -50.15
# (ii) Non-controlling interest                                         -50.92
# nan                                                                      NaN
# Other comprehensive income/(loss) attributable to:                       NaN
# (i) Equity holders of the Company                                     -42.46
# (ii) Non-controlling interest                                            NaN
# nan                                                                      NaN
# Total comprehensive income/(loss) attributable to:                       NaN
# (i) Equity holders of the Company                                     -92.61
# (ii) Non-controlling interest                                         -50.92
# nan                                                                      NaN
# Earnings per equity share (nominal value of 4 e...                       NaN
# Basic                                                                  -1.78
# Diluted                                                                -1.78
#
#                                                     As at March 31, 2020  \
# Profit and Loss
# Income                                                               NaN
# Revenue from operations                                          2475.09
# Other income                                                      146.37
# Total income                                                     2621.46
# nan                                                                  NaN
# Expenses                                                             NaN
# Content, event and web server                                     506.92
# Advertising and promotion                                        1329.26
# Commission                                                         70.72
# Employee benefits                                                 318.67
# Finance costs                                                      12.37
# Depreciation and amortization                                     268.81
# Others                                                            304.75
# Total expenses                                                   2811.50
# nan                                                                  NaN
# Profit/(Loss) before exceptional items, share o...               -190.04
# Share of loss of Investments accounted using eq...                -18.12
# (Loss)/profit before exceptional items and tax                   -208.16
# Exceptional items                                                    NaN
# (Loss)/profit before tax                                         -208.16
# Tax expense:                                                         NaN
# Current tax                                                        55.57
# Deferred tax                                                        2.42
# Total tax expense                                                  57.99
# nan                                                                  NaN
# Net (loss)/profit                                                -266.15
# nan                                                                  NaN
# Other comprehensive income                                           NaN
# nan                                                                  NaN
# Items that will not be reclassified to profit a...                   NaN
# Re-measurements of defined employee benefit plans                   1.00
# Income tax relating to items that will not be r...                 -0.27
# Items that may be reclassified to profit or loss:                    NaN
# Net profit/(loss) on FVOCI debt instruments                        14.38
# Exchange differences in translating the financi...                146.19
# Income tax relating to items that will be recla...                   NaN
# Total other comprehensive income/(loss)                           161.30
# nan                                                                  NaN
# Total comprehensive income/(loss)                                -104.85
# nan                                                                  NaN
# Profit/(loss) attributable to:                                       NaN
# (i) Equity holders of the Company                                 -21.26
# (ii) Non-controlling interest                                    -244.89
# nan                                                                  NaN
# Other comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                 161.30
# (ii) Non-controlling interest                                        NaN
# nan                                                                  NaN
# Total comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                 140.04
# (ii) Non-controlling interest                                    -244.89
# nan                                                                  NaN
# Earnings per equity share (nominal value of 4 e...                   NaN
# Basic                                                              -0.77
# Diluted                                                            -0.77
#
#                                                     As at March 31, 2019  \
# Profit and Loss
# Income                                                               NaN
# Revenue from operations                                          1696.98
# Other income                                                      164.00
# Total income                                                     1860.98
# nan                                                                  NaN
# Expenses                                                             NaN
# Content, event and web server                                     442.95
# Advertising and promotion                                         272.48
# Commission                                                         31.31
# Employee benefits                                                 413.84
# Finance costs                                                      13.84
# Depreciation and amortization                                     195.44
# Others                                                            372.94
# Total expenses                                                   1742.80
# nan                                                                  NaN
# Profit/(Loss) before exceptional items, share o...                118.18
# Share of loss of Investments accounted using eq...                 -9.47
# (Loss)/profit before exceptional items and tax                    108.71
# Exceptional items                                                    NaN
# (Loss)/profit before tax                                          108.71
# Tax expense:                                                         NaN
# Current tax                                                        69.65
# Deferred tax                                                      -28.07
# Total tax expense                                                  41.58
# nan                                                                  NaN
# Net (loss)/profit                                                  67.13
# nan                                                                  NaN
# Other comprehensive income                                           NaN
# nan                                                                  NaN
# Items that will not be reclassified to profit a...                   NaN
# Re-measurements of defined employee benefit plans                  -1.69
# Income tax relating to items that will not be r...                 -0.45
# Items that may be reclassified to profit or loss:                    NaN
# Net profit/(loss) on FVOCI debt instruments                         0.23
# Exchange differences in translating the financi...                114.81
# Income tax relating to items that will be recla...                   NaN
# Total other comprehensive income/(loss)                           112.90
# nan                                                                  NaN
# Total comprehensive income/(loss)                                 180.03
# nan                                                                  NaN
# Profit/(loss) attributable to:                                       NaN
# (i) Equity holders of the Company                                 175.08
# (ii) Non-controlling interest                                    -107.95
# nan                                                                  NaN
# Other comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                 112.90
# (ii) Non-controlling interest                                        NaN
# nan                                                                  NaN
# Total comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                 287.98
# (ii) Non-controlling interest                                    -107.95
# nan                                                                  NaN
# Earnings per equity share (nominal value of 4 e...                   NaN
# Basic                                                               6.39
# Diluted                                                             6.27
#
#                                                     As at March 31, 2018  \
# Profit and Loss
# Income                                                               NaN
# Revenue from operations                                          1720.40
# Other income                                                       99.00
# Total income                                                     1819.40
# nan                                                                  NaN
# Expenses                                                             NaN
# Content, event and web server                                     121.35
# Advertising and promotion                                         427.80
# Commission                                                         32.26
# Employee benefits                                                 371.97
# Finance costs                                                      18.34
# Depreciation and amortization                                      82.16
# Others                                                            279.84
# Total expenses                                                   1333.72
# nan                                                                  NaN
# Profit/(Loss) before exceptional items, share o...                485.68
# Share of loss of Investments accounted using eq...                 -0.63
# (Loss)/profit before exceptional items and tax                    485.05
# Exceptional items                                                -357.18
# (Loss)/profit before tax                                          127.87
# Tax expense:                                                         NaN
# Current tax                                                       143.65
# Deferred tax                                                      -26.01
# Total tax expense                                                 117.64
# nan                                                                  NaN
# Net (loss)/profit                                                  10.23
# nan                                                                  NaN
# Other comprehensive income                                           NaN
# nan                                                                  NaN
# Items that will not be reclassified to profit a...                   NaN
# Re-measurements of defined employee benefit plans                   0.21
# Income tax relating to items that will not be r...                 -0.07
# Items that may be reclassified to profit or loss:                    NaN
# Net profit/(loss) on FVOCI debt instruments                        -1.31
# Exchange differences in translating the financi...                 16.81
# Income tax relating to items that will be recla...                   NaN
# Total other comprehensive income/(loss)                            15.64
# nan                                                                  NaN
# Total comprehensive income/(loss)                                  25.87
# nan                                                                  NaN
# Profit/(loss) attributable to:                                       NaN
# (i) Equity holders of the Company                                  26.70
# (ii) Non-controlling interest                                     -16.47
# nan                                                                  NaN
# Other comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                  15.64
# (ii) Non-controlling interest                                        NaN
# nan                                                                  NaN
# Total comprehensive income/(loss) attributable to:                   NaN
# (i) Equity holders of the Company                                  42.34
# (ii) Non-controlling interest                                     -16.47
# nan                                                                  NaN
# Earnings per equity share (nominal value of 4 e...                   NaN
# Basic                                                               1.05
# Diluted                                                             1.04
#
#                                                     YoY 2019-2020  \
# Profit and Loss
# Income                                                   0.000000
# Revenue from operations                                 45.852632
# Other income                                           -10.750000
# Total income                                            40.864491
# nan                                                      0.000000
# Expenses                                                 0.000000
# Content, event and web server                           14.441811
# Advertising and promotion                              387.837639
# Commission                                             125.870329
# Employee benefits                                      -22.996810
# Finance costs                                          -10.621387
# Depreciation and amortization                           37.540933
# Others                                                 -18.284443
# Total expenses                                          61.320863
# nan                                                      0.000000
# Profit/(Loss) before exceptional items, share o...    -260.805551
# Share of loss of Investments accounted using eq...      91.341077
# (Loss)/profit before exceptional items and tax        -291.481924
# Exceptional items                                        0.000000
# (Loss)/profit before tax                              -291.481924
# Tax expense:                                             0.000000
# Current tax                                            -20.215363
# Deferred tax                                          -108.621304
# Total tax expense                                       39.466089
# nan                                                      0.000000
# Net (loss)/profit                                     -496.469537
# nan                                                      0.000000
# Other comprehensive income                               0.000000
# nan                                                      0.000000
# Items that will not be reclassified to profit a...       0.000000
# Re-measurements of defined employee benefit plans     -159.171598
# Income tax relating to items that will not be r...     -40.000000
# Items that may be reclassified to profit or loss:        0.000000
# Net profit/(loss) on FVOCI debt instruments           6152.173913
# Exchange differences in translating the financi...      27.332114
# Income tax relating to items that will be recla...       0.000000
# Total other comprehensive income/(loss)                 42.869796
# nan                                                      0.000000
# Total comprehensive income/(loss)                     -158.240293
# nan                                                      0.000000
# Profit/(loss) attributable to:                           0.000000
# (i) Equity holders of the Company                     -112.143020
# (ii) Non-controlling interest                          126.855025
# nan                                                      0.000000
# Other comprehensive income/(loss) attributable to:       0.000000
# (i) Equity holders of the Company                       42.869796
# (ii) Non-controlling interest                            0.000000
# nan                                                      0.000000
# Total comprehensive income/(loss) attributable to:       0.000000
# (i) Equity holders of the Company                      -51.371623
# (ii) Non-controlling interest                          126.855025
# nan                                                      0.000000
# Earnings per equity share (nominal value of 4 e...       0.000000
# Basic                                                 -112.050078
# Diluted                                               -112.280702
#
#                                                     YoY 2018-2019        CAGR
# Profit and Loss
# Income                                                   0.000000    0.000000
# Revenue from operations                                 -1.361311   19.944622
# Other income                                            65.656566   21.592962
# Total income                                             2.285369   20.034897
# nan                                                      0.000000    0.000000
# Expenses                                                 0.000000    0.000000
# Content, event and web server                          265.018541  104.385378
# Advertising and promotion                              -36.306685   76.272506
# Commission                                              -2.944823   48.060409
# Employee benefits                                       11.256284   -7.441431
# Finance costs                                          -24.536532  -17.873147
# Depreciation and amortization                          137.877313   80.880810
# Others                                                  33.269011    4.355889
# Total expenses                                          30.672105   45.190002
# nan                                                      0.000000    0.000000
# Profit/(Loss) before exceptional items, share o...     -75.667106         NaN
# Share of loss of Investments accounted using eq...    1403.174603  436.301266
# (Loss)/profit before exceptional items and tax         -77.587878         NaN
# Exceptional items                                        0.000000    0.000000
# (Loss)/profit before tax                               -14.983968         NaN
# Tax expense:                                             0.000000    0.000000
# Current tax                                            -51.514097  -37.803294
# Deferred tax                                             7.920031         NaN
# Total tax expense                                      -64.654879  -29.789988
# nan                                                      0.000000    0.000000
# Net (loss)/profit                                      556.207234         NaN
# nan                                                      0.000000    0.000000
# Other comprehensive income                               0.000000    0.000000
# nan                                                      0.000000    0.000000
# Items that will not be reclassified to profit a...       0.000000    0.000000
# Re-measurements of defined employee benefit plans     -904.761905  118.217890
# Income tax relating to items that will not be r...     542.857143   96.396101
# Items that may be reclassified to profit or loss:        0.000000    0.000000
# Net profit/(loss) on FVOCI debt instruments           -117.557252         NaN
# Exchange differences in translating the financi...     582.986318  194.900138
# Income tax relating to items that will be recla...       0.000000    0.000000
# Total other comprehensive income/(loss)                621.867008  221.143258
# nan                                                      0.000000    0.000000
# Total comprehensive income/(loss)                      595.902590         NaN
# nan                                                      0.000000    0.000000
# Profit/(loss) attributable to:                           0.000000    0.000000
# (i) Equity holders of the Company                      555.730337         NaN
# (ii) Non-controlling interest                          555.434123  285.601510
# nan                                                      0.000000    0.000000
# Other comprehensive income/(loss) attributable to:       0.000000    0.000000
# (i) Equity holders of the Company                      621.867008  221.143258
# (ii) Non-controlling interest                            0.000000    0.000000
# nan                                                      0.000000    0.000000
# Total comprehensive income/(loss) attributable to:       0.000000    0.000000
# (i) Equity holders of the Company                      580.160605   81.865627
# (ii) Non-controlling interest                          555.434123  285.601510
# nan                                                      0.000000    0.000000
# Earnings per equity share (nominal value of 4 e...       0.000000    0.000000
# Basic                                                  508.571429         NaN
# Diluted                                                502.884615         NaN

# %%
# Assuming indexed_df is your DataFrame

# Temporarily reset the index for styling
temp_df = indexed_df.reset_index()

# Convert string 'nan' to actual NaN values in 'Profit and Loss' column
temp_df['Profit and Loss'] = temp_df['Profit and Loss'].replace('nan', np.nan)

# Drop rows where 'Profit and Loss' column contains NaN
temp_df = temp_df.dropna(subset=['Profit and Loss'])

# Define the styling function to apply bold only to rows where the index contains 'Total'
def bold_if_total_in_index(row):
    if 'Total' in row['Profit and Loss']:
        return ['font-weight: bold'] * len(row)
    else:
        return [''] * len(row)

# Apply the styling
styled_df = temp_df.style.apply(bold_if_total_in_index, axis=1)

# Assume 'numeric_columns' is a list of the names of your numeric columns
numeric_columns = ['As at September 30, 2020', 'As at March 31, 2020', 'As at March 31, 2019', 'As at March 31, 2018', 'YoY 2019-2020', 'YoY 2018-2019', 'CAGR']

# Apply number formatting only to numeric columns
styled_df = styled_df.format({col: "{:.2f}" for col in numeric_columns})

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_d82e5_row3_col0, #T_d82e5_row3_col1, #T_d82e5_row3_col2, #T_d82e5_row3_col3, #T_d82e5_row3_col4, #T_d82e5_row3_col5, #T_d82e5_row3_col6, #T_d82e5_row3_col7, #T_d82e5_row12_col0, #T_d82e5_row12_col1, #T_d82e5_row12_col2, #T_d82e5_row12_col3, #T_d82e5_row12_col4, #T_d82e5_row12_col5, #T_d82e5_row12_col6, #T_d82e5_row12_col7, #T_d82e5_row21_col0, #T_d82e5_row21_col1, #T_d82e5_row21_col2, #T_d82e5_row21_col3, #T_d82e5_row21_col4, #T_d82e5_row21_col5, #T_d82e5_row21_col6, #T_d82e5_row21_col7, #T_d82e5_row31_col0, #T_d82e5_row31_col1, #T_d82e5_row31_col2, #T_d82e5_row31_col3, #T_d82e5_row31_col4, #T_d82e5_row31_col5, #T_d82e5_row31_col6, #T_d82e5_row31_col7, #T_d82e5_row32_col0, #T_d82e5_row32_col1, #T_d82e5_row32_col2, #T_d82e5_row32_col3, #T_d82e5_row32_col4, #T_d82e5_row32_col5, #T_d82e5_row32_col6, #T_d82e5_row32_col7, #T_d82e5_row39_col0, #T_d82e5_row39_col1, #T_d82e5_row39_col2, #T_d82e5_row39_col3, #T_d82e5_row39_col4, #T_d82e5_row39_col5, #T_d82e5_row39_col6, #T_d82e5_row39_col7 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d82e5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Profit and Loss</th>
#       <th class="col_heading level0 col1" >As at September 30, 2020</th>
#       <th class="col_heading level0 col2" >As at March 31, 2020</th>
#       <th class="col_heading level0 col3" >As at March 31, 2019</th>
#       <th class="col_heading level0 col4" >As at March 31, 2018</th>
#       <th class="col_heading level0 col5" >YoY 2019-2020</th>
#       <th class="col_heading level0 col6" >YoY 2018-2019</th>
#       <th class="col_heading level0 col7" >CAGR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d82e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d82e5_row0_col0" class="data row0 col0" >Income</td>
#       <td id="T_d82e5_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_d82e5_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_d82e5_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_d82e5_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_d82e5_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_d82e5_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_d82e5_row0_col7" class="data row0 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d82e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d82e5_row1_col0" class="data row1 col0" >Revenue from operations</td>
#       <td id="T_d82e5_row1_col1" class="data row1 col1" >2004.57</td>
#       <td id="T_d82e5_row1_col2" class="data row1 col2" >2475.09</td>
#       <td id="T_d82e5_row1_col3" class="data row1 col3" >1696.98</td>
#       <td id="T_d82e5_row1_col4" class="data row1 col4" >1720.40</td>
#       <td id="T_d82e5_row1_col5" class="data row1 col5" >45.85</td>
#       <td id="T_d82e5_row1_col6" class="data row1 col6" >-1.36</td>
#       <td id="T_d82e5_row1_col7" class="data row1 col7" >19.94</td>
#     </tr>
#     <tr>
#       <th id="T_d82e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d82e5_row2_col0" class="data row2 col0" >Other income</td>
#       <td id="T_d82e5_row2_col1" class="data row2 col1" >65.49</td>
#       <td id="T_d82e5_row2_col2" class="data row2 col2" >146.37</td>
#       <td id="T_d82e5_row2_col3" class="data row2 col3" >164.00</td>
#       <td id="T_d82e5_row2_col4" class="data row2 col4" >99.00</td>
#       <td id="T_d82e5_row2_col5" class="data row2 col5" >-10.75</td>
#       <td id="T_d82e5_row2_col6" class="data row2 col6" >65.66</td>
#       <td id="T_d82e5_row2_col7" class="data row2 col7" >21.59</td>
#     </tr>
#     <tr>
#       <th id="T_d82e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d82e5_row3_col0" class="data row3 col0" >Total income</td>
#       <td id="T_d82e5_row3_col1" class="data row3 col1" >2070.06</td>
#       <td id="T_d82e5_row3_col2" class="data row3 col2" >2621.46</td>
#       <td id="T_d82e5_row3_col3" class="data row3 col3" >1860.98</td>
#       <td id="T_d82e5_row3_col4" class="data row3 col4" >1819.40</td>
#       <td id="T_d82e5_row3_col5" class="data row3 col5" >40.86</td>
#       <td id="T_d82e5_row3_col6" class="data row3 col6" >2.29</td>
#       <td id="T_d82e5_row3_col7" class="data row3 col7" >20.03</td>
#     </tr>
#     <tr>
#       <th id="T_d82e5_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d82e5_row4_col0" class="data row4 col0" >Expenses</td>
#       <td id="T_d82e5_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_d82e5_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_d82e5_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_d82e5_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_d82e5_row4_col5" class="data row4 col5" >0.00</td>
#       <td id="T_d82e5_row4_col6" class="data row4 col6" >0.00</td>
#       <td id="T_d82e5_row4_col7" class="data row4 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d82e5_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d82e5_row5_col0" class="data row5 col0" >Content, event and web server</td>
#       <td id="T_d82e5_row5_col1" class="data row5 col1" >151.97</td>
#       <td id="T_d82e5_row5_col2" class="data row5 col2" >506.92</td>
#       <td id="T_d82e5_row5_col3" class="data row5 col3" >442.95</td>
#       <td id="T_d82e5_row5_col4" class="data row5 col4" >121.35</td>
#       <td id="T_d82e5_row5_col5" class="data row5 col5" >14.44</td>
#       <td id="T_d82e5_row5_col6" class="data row5 col6" >265.02</td>
#       <td id="T_d82e5_row5_col7" class="data row5 col7" >104.39</td>
#     </tr>
#     <tr>
#       <th id="T_d82e5_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_d82e5_row6_col0" class="data row6 col0" >Advertising and promotion</td>
#       <td id="T_d82e5_row6_col1" class="data row6 col1" >1196.24</td>
#       <td id="T_d82e5_row6_col2" class="data row6 col2" >1329.26</td>
#       <td id="T_d82e5_row6_col3" class="data row6 col3" >272.48</td>
#       <td id="T_d82e5_row6_col4" class="data row6 col4" >427.80</td>
#       <td id="T_d82e5_row6_col5" class="data row6 col5" >387.84</td>
#       <td id="T_d82e5_row6_col6" class="data row6 col6" >-36.31</td>
#       <td id="T_d82e5_row6_col7" class="data row6 col7" >76.27</td>
#     </tr>
#     <tr>
#       <th id="T_d82e5_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_d82e5_row7_col0" class="data row7 col0" >Commission</td>
#       <td id="T_d82e5_row7_col1" class="data row7 col1" >222.66</td>
#       <td id="T_d82e5_row7_col2" class="data row7 col2" >70.72</td>
#       <td id="T_d82e5_row7_col3" class="data row7 col3" >31.31</td>
#       <td id="T_d82e5_row7_col4" class="data row7 col4" >32.26</td>
#       <td id="T_d82e5_row7_col5" class="data row7 col5" >125.87</td>
#       <td id="T_d82e5_row7_col6" class="data row7 col6" >-2.94</td>
#       <td id="T_d82e5_row7_col7" class="data row7 col7" >48.06</td>
#     </tr>
#     <tr>
#       <th id="T_d82e5_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_d82e5_row8_col0" class="data row8 col0" >Employee benefits</td>
#       <td id="T_d82e5_row8_col1" class="data row8 col1" >218.54</td>
#       <td id="T_d82e5_row8_col2" class="data row8 col2" >318.67</td>
#       <td id="T_d82e5_row8_col3" class="data row8 col3" >413.84</td>
#       <td id="T_d82e5_row8_col4" class="data row8 col4" >371.97</td>
#       <td id="T_d82e5_row8_col5" class="data row8 col5" >-23.00</td>
#       <td id="T_d82e5_row8_col6" class="data row8 col6" >11.26</td>
#       <td id="T_d82e5_row8_col7" class="data row8 col7" >-7.44</td>
#     </tr>
#     <tr>
#       <th id="T_d82e5_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_d82e5_row9_col0" class="data row9 col0" >Finance costs</td>
#       <td id="T_d82e5_row9_col1" class="data row9 col1" >5.11</td>
#       <td id="T_d82e5_row9_col2" class="data row9 col2" >12.37</td>
#       <td id="T_d82e5_row9_col3" class="data row9 col3" >13.84</td>
#       <td id="T_d82e5_row9_col4" class="data row9 col4" >18.34</td>
#       <td id="T_d8

# %%
# Define the path where you want to save the Excel file
file_path = '/Users/mohjaiswal/Desktop/ArthyaInvest/PNL_financial_statement1.xlsx'  # Update this to your desired path

# Save the styled DataFrame to Excel at the specified path
styled_df.to_excel(file_path, engine='openpyxl', index=False)
